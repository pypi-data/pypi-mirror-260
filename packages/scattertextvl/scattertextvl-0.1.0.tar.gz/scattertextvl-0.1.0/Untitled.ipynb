# %%
import scattertext as st
import scattertextvl as stvl
import pandas as pd
import spacy

# %%
nlp = spacy.load('en_core_web_sm')

convention_df = st.SampleCorpora.ConventionData2012.get_data().assign(
    Party=lambda df: df.party.apply(lambda x: {'democrat': 'Dem', 'republican': 'GOP'}[x]),
    Parse=lambda df: df.text.progress_apply(nlp)
)
# Out:
#   0%|          | 0/189 [00:00<?, ?it/s]

# %%
biber_corpus = st.OffsetCorpusFactory(
    convention_df,
    category_col='Party',
    parsed_col='Parse',
    feat_and_offset_getter=stvl.BiberOffsetGetter()
).build(show_progress=True)

biber_stat_df = st.HedgesG(
    biber_corpus
).use_metadata().set_categories(
    category_name='Dem'
).get_score_df(
).assign(
    Frequency=lambda df: df.count1 + df.count2,
    X=lambda df: df.Frequency,
    Y=lambda df: df.hedges_g,
    Xpos=lambda df: st.Scalers.dense_rank(df.X),
    Ypos=lambda df: st.Scalers.scale_center_zero_abs(df.Y),
    ColorScore=lambda df: df.Ypos,
)
# Out:
# /Users/jasonkessler/github/scattertextvl/scattertextvl/features/biber_offset_getter.py:13: UserWarning: In addition to citing Scattertext, cite as:
# Elen Le Foll and Muhammad Shakir. MFTE Python 1.0. 2023. https://github.com/mshakirDr/MFTE
#   warnings.warn(
#   0%|          | 0/189 [00:00<?, ?it/s]

# %%
plot_df = pd.merge(
    biber_stat_df,
    stvl.get_biber_feature_df(),
    left_index=True,
    right_index=True
).reset_index().rename(columns={'index': 'term'}).set_index('term')

# %%
plot_df
# Out:
#          cohens_d  cohens_d_se  cohens_d_z  cohens_d_p  hedges_g  hedges_g_se
# term
# VPRT     0.046555     0.145502    0.319957    0.374500  0.046370     0.151662  \
# COMM    -0.046474     0.145502   -0.319406    0.625291 -0.046290     0.151662
# POLITE  -0.092687     0.145561   -0.636758    0.737859 -0.092319     0.151773
# PP2     -0.147069     0.145679   -1.009537    0.843641 -0.146484     0.151998
# EMPH     0.057484     0.145513    0.395042    0.346406  0.057255     0.151681
# ...           ...          ...         ...         ...       ...          ...
# ThNLIK   0.025878     0.145489    0.177866    0.429414  0.025775     0.151636
# QUTAG   -0.239293     0.146002   -1.638967    0.949390 -0.238342     0.152612
# ToJCRTN -0.326109     0.146446   -2.226813    0.987020 -0.324813     0.153454
# ThJLIK  -0.211455     0.145889   -1.449427    0.926391 -0.210615     0.152396
# ThNNFCT -0.211455     0.145889   -1.449427    0.926391 -0.210615     0.152396
#
#          hedges_g_z  hedges_g_p        m1        m2  ...     X         Y
# term                                                 ...
# VPRT       0.305743    0.379900  0.036398  0.035930  ...  9468  0.046370  \
# COMM      -0.305216    0.619899  0.007153  0.007326  ...  1945 -0.046290
# POLITE    -0.608269    0.728495  0.001680  0.001940  ...   377 -0.092319
# PP2       -0.963723    0.832408  0.006259  0.007055  ...  1875 -0.146484
# EMPH       0.377470    0.352912  0.003212  0.002780  ...   701  0.057255
# ...             ...         ...       ...       ...  ...   ...       ...
# ThNLIK     0.169978    0.432514  0.000015  0.000011  ...     3  0.025775
# QUTAG     -1.561752    0.940827  0.000016  0.000064  ...     8 -0.238342
# ToJCRTN   -2.116681    0.982857  0.000000  0.000029  ...     3 -0.324813
# ThJLIK    -1.382021    0.916517  0.000000  0.000005  ...     1 -0.210615
# ThNNFCT   -1.382021    0.916517  0.000000  0.000008  ...     1 -0.210615
#
#              Xpos      Ypos  ColorScore                Category
# term
# VPRT     0.979730  0.551099    0.551099           Verb features  \
# COMM     0.777027  0.448989    0.448989          Verb semantics
# POLITE   0.432432  0.398266    0.398266   Stance-taking devices
# PP2      0.763514  0.338576    0.338576                Pronouns
# EMPH     0.621622  0.563095    0.563095   Stance-taking devices
# ...           ...       ...         ...                     ...
# ThNLIK   0.013514  0.528403    0.528403                  Syntax
# QUTAG    0.040541  0.237350    0.237350  Discourse organisation
# ToJCRTN  0.013514  0.142060    0.142060                  Syntax
# ThJLIK   0.000000  0.267905    0.267905                  Syntax
# ThNNFCT  0.000000  0.267905    0.267905                  Syntax
#
#                                                    Feature
# term
# VPRT                                         Present tense  \
# COMM                                   Communication verbs
# POLITE                                  Politeness markers
# PP2                             Reference to  addressee(s)
# EMPH                                             Emphatics
# ...                                                    ...
# ThNLIK   that subordinate clauses (relative clauses) pr...
# QUTAG                                        Question tags
# ToJCRTN        to clauses preceded by certainty adjectives
# ThJLIK   that subordinate clauses (other than relatives...
# ThNNFCT  that subordinate clauses (relative clauses) pr...
#
#                                                   Examples
# term
# VPRT               It’s ours. Who doesn’t love it? I know.  \
# COMM     Describe it to your partner and say why. Write...
# POLITE   Can you open the window, please? Would you min...
# PP2      If your model was good enough, you’d be able t...
# EMPH     I do wish I hadn't drunk quite so much. Oh rea...
# ...                                                    ...
# ThNLIK   It was a feeling that I never had until that n...
# QUTAG    Do they? Were you? It’s just it’s repetitive, ...
# ToJCRTN  I always make sure to have a big bottle of wat...
# ThJLIK   This makes it unlikely that such a fund will b...
# ThNNFCT  The comments that follow are intended to help ...
#
#                                         Operationalization  NormalizationUnit
# term
# VPRT     Subsumes the VBP (present tense other than thi...       Finite verbs
# COMM     Following Biber (2006: 247, based on the LGSWE...       Finite verbs
# POLITE   Assigned to all occurrences of thanks, thank y...              Words
# PP2      Following Biber (1988), all occurrences of you...       Finite verbs
# EMPH     Originally based on Biber (1988), assigned to ...              Words
# ...                                                    ...                ...
# ThNLIK   That relative clause (THRC) tag preceded by an...              Nouns
# QUTAG    Assigned to question marks preceded by (1) inn...       Finite verbs
# ToJCRTN  To immediately followed by a verb and  precede...              Words
# ThJLIK   That complement clause (THSC) tag preceded by ...       Finite verbs
# ThNNFCT  That relative clause (THRC) tag preceded by an...              Nouns
#
# [154 rows x 25 columns]

# %%
html = st.dataframe_scattertext(
    biber_corpus,
    plot_df=plot_df,
    category='Dem',
    category_name='Democratic',
    not_category_name='Republican',
    width_in_pixels=1000,
    suppress_text_column='Display',
    metadata=lambda c: c.get_df()['speaker'],
    use_non_text_features=True,
    ignore_categories=False,
    use_offsets=True,
    unified_context=False,
    horizontal_line_y_position=0,
    color_score_column='ColorScore',
    left_list_column='ColorScore',
    y_label='Hedges G',
    x_label='Frequency Ranks',
    y_axis_labels=[f'More Rep: g=-{plot_df.hedges_g.abs().max():.3f}',
                   '0',
                   f'More Dem: g={plot_df.hedges_g.abs().max():.3f}'],
    tooltip_columns=['Frequency', 'hedges_g'],
    term_description_columns=['Feature', 'Category', 'Examples',
                              'hedges_g', 'hedges_g_p', 'Frequency', 'Operationalization'],
    term_description_column_names={'hedges_g': "Hedge's g",
                                   'hedges_g_p': "Hedge's g p-value"},
    header_names={'upper': 'Top Democratic', 'lower': 'Top Republican'},
    term_word_in_term_description='Biber Tag',
)

fn = 'demo_biber.html'
with open(fn, 'w') as of:
    of.write(html)
print(f'run open ./{fn}')
# Out:
# There are metadata in the corpus which are not in the index of plot_df. These will not be available in the visualization. These are: ['H', '.', 'XX', 'OMP', 'P', ',', 'COMP', ':', '``', 'ToThNSTNCall', 'PH', '-LRB-', '_SP', 'NFP', "''", 'PP1all', 'PP3t', 'YPH', 'AFX', 'MP', '$', 'HYPH', 'PP3all'].s
# run open ./demo_biber.html

# %%
biber_category_corpus = biber_corpus.rename_metadata(
    stvl.get_biber_feature_df().reset_index()[['index','Category']].values
)

# %%
biber_category_stat_df = st.CohensD(biber_category_corpus).use_metadata().set_categories(
    'Dem', ['GOP']
).get_score_df(
).assign(
    Frequency = lambda df: df.count1+df.count2,
    X=lambda df: df.Frequency,
    Y=lambda df: df.hedges_g,
    Xpos=lambda df: st.Scalers.dense_rank(df.X),
    Ypos=lambda df: st.Scalers.scale_center_zero_abs(df.Y),
    ColorScore=lambda df: df.Ypos,
    Features = stvl.get_biber_feature_df().groupby('Category').apply(
        lambda gdf: ', '.join(gdf.Feature)
    )
)
plot_df = pd.merge(
    biber_category_stat_df,
    stvl.get_biber_feature_df().set_index('Category'),
    left_index=True,
    right_index=True
).reset_index().rename(columns={'index': 'term'}).set_index('term')

# %%
plot_df
# Out:
# ['Adjective semantics', 'Adjectives', 'Adverb semantics', 'Adverbials', 'Adverbs', 'Determinatives', 'Discourse organisation', 'Lexis', 'Negation', 'Noun semantics', 'Nouns', 'Prepositions', 'Pronouns', 'Stance-taking devices', 'Stative forms', 'Syntax', 'Verb features', 'Verb semantics']
#                      cohens_d  cohens_d_se  cohens_d_z  cohens_d_p  hedges_g
# term
# Adjective semantics -0.140232     0.145661   -0.962728    0.832158 -0.139675  \
# Adjective semantics -0.140232     0.145661   -0.962728    0.832158 -0.139675
# Adjective semantics -0.140232     0.145661   -0.962728    0.832158 -0.139675
# Adjective semantics -0.140232     0.145661   -0.962728    0.832158 -0.139675
# Adjective semantics -0.140232     0.145661   -0.962728    0.832158 -0.139675
# ...                       ...          ...         ...         ...       ...
# Verb semantics       0.016570     0.145485    0.113893    0.454661  0.016504
# Verb semantics       0.016570     0.145485    0.113893    0.454661  0.016504
# Verb semantics       0.016570     0.145485    0.113893    0.454661  0.016504
# Verb semantics       0.016570     0.145485    0.113893    0.454661  0.016504
# Verb semantics       0.016570     0.145485    0.113893    0.454661  0.016504
#
#                      hedges_g_se  hedges_g_z  hedges_g_p        m1        m2
# term
# Adjective semantics     0.151964   -0.919132    0.820987  0.008229  0.008833  \
# Adjective semantics     0.151964   -0.919132    0.820987  0.008229  0.008833
# Adjective semantics     0.151964   -0.919132    0.820987  0.008229  0.008833
# Adjective semantics     0.151964   -0.919132    0.820987  0.008229  0.008833
# Adjective semantics     0.151964   -0.919132    0.820987  0.008229  0.008833
# ...                          ...         ...         ...       ...       ...
# Verb semantics          0.151629    0.108844    0.456663  0.073426  0.073144
# Verb semantics          0.151629    0.108844    0.456663  0.073426  0.073144
# Verb semantics          0.151629    0.108844    0.456663  0.073426  0.073144
# Verb semantics          0.151629    0.108844    0.456663  0.073426  0.073144
# Verb semantics          0.151629    0.108844    0.456663  0.073426  0.073144
#
#                      ...      X         Y      Xpos      Ypos  ColorScore
# term                 ...
# Adjective semantics  ...   1977 -0.139675  0.176471  0.305760    0.305760  \
# Adjective semantics  ...   1977 -0.139675  0.176471  0.305760    0.305760
# Adjective semantics  ...   1977 -0.139675  0.176471  0.305760    0.305760
# Adjective semantics  ...   1977 -0.139675  0.176471  0.305760    0.305760
# Adjective semantics  ...   1977 -0.139675  0.176471  0.305760    0.305760
# ...                  ...    ...       ...       ...       ...         ...
# Verb semantics       ...  17571  0.016504  0.764706  0.522951    0.522951
# Verb semantics       ...  17571  0.016504  0.764706  0.522951    0.522951
# Verb semantics       ...  17571  0.016504  0.764706  0.522951    0.522951
# Verb semantics       ...  17571  0.016504  0.764706  0.522951    0.522951
# Verb semantics       ...  17571  0.016504  0.764706  0.522951    0.522951
#
#                                                               Features
# term
# Adjective semantics  Attitudinal adjectives without a that clause a...  \
# Adjective semantics  Attitudinal adjectives without a that clause a...
# Adjective semantics  Attitudinal adjectives without a that clause a...
# Adjective semantics  Attitudinal adjectives without a that clause a...
# Adjective semantics  Attitudinal adjectives without a that clause a...
# ...                                                                ...
# Verb semantics       DO auxiliary, Necessity modals, Modal can, Mod...
# Verb semantics       DO auxiliary, Necessity modals, Modal can, Mod...
# Verb semantics       DO auxiliary, Necessity modals, Modal can, Mod...
# Verb semantics       DO auxiliary, Necessity modals, Modal can, Mod...
# Verb semantics       DO auxiliary, Necessity modals, Modal can, Mod...
#
#                                                                Feature
# term
# Adjective semantics  Attitudinal adjectives without a that clause a...  \
# Adjective semantics                        Adjectives related to color
# Adjective semantics   Epistemic adjectives without a that clause after
# Adjective semantics                              Evaluative adjectives
# Adjective semantics                              Relational adjectives
# ...                                                                ...
# Verb semantics                         factive verbs in other contexts
# Verb semantics                      likelihood verbs in other contexts
# Verb semantics                               All modals of possibility
# Verb semantics                                All modals of prediction
# Verb semantics                                BE as an auxilliary verb
#
#                                                               Examples
# term
# Adjective semantics  I was surprised when it arrived in a plastic w...  \
# Adjective semantics  She had luxuriously long black hair, a sprinkl...
# Adjective semantics  Tell me the true story then. Possible but unli...
# Adjective semantics  She was fine when she left them, she looked gr...
# Adjective semantics  They were very different people. Her original ...
# ...                                                                ...
# Verb semantics       We're going to find her. It was a minute or tw...
# Verb semantics       The joke was on him, we presume. To be able to...
# Verb semantics       Can I give him a hint? You cannot. May I have ...
# Verb semantics       It won’t do. Shall we see? Wouldn't you like t...
# Verb semantics       I'm going there on Wednesday. Because he's bas...
#
#                                                     Operationalization
# term
# Adjective semantics  Any of the following words tagged as adjective...  \
# Adjective semantics  Any of the following words tagged as adjective...
# Adjective semantics  Any of the following words tagged as adjective...
# Adjective semantics  Any of the following words tagged as adjective...
# Adjective semantics  Any of the following words tagged as adjective...
# ...                                                                ...
# Verb semantics       Any word in the following list tagged as verb ...
# Verb semantics       Any word in the following list tagged as verb ...
# Verb semantics                    Any word tagged as MDCA, MDCO, MDMM.
# Verb semantics                     Any word tagged as MDWS, MDWO, GTO.
# Verb semantics       This feature is only tagged to be able to coun...
#
#                      NormalizationUnit
# term
# Adjective semantics              Nouns
# Adjective semantics              Nouns
# Adjective semantics              Nouns
# Adjective semantics              Nouns
# Adjective semantics              Nouns
# ...                                ...
# Verb semantics            Finite verbs
# Verb semantics            Finite verbs
# Verb semantics            Finite verbs
# Verb semantics            Finite verbs
# Verb semantics
#
# [166 rows x 25 columns]

# %%
html = st.dataframe_scattertext(
    biber_category_corpus,
    plot_df=plot_df,
    category='Dem',
    category_name='Democratic',
    not_category_name='Republican',
    width_in_pixels=1000,
    suppress_text_column='Display',
    metadata=lambda c: c.get_df()['speaker'],
    use_non_text_features=True,
    ignore_categories=False,
    use_offsets=True,
    unified_context=False,
    horizontal_line_y_position=0,
    color_score_column='ColorScore',
    left_list_column='ColorScore',
    y_label='Hedges G',
    x_label='Frequency Ranks',
    y_axis_labels=[f'More Rep: g=-{plot_df.hedges_g.abs().max():.3f}',
                   '0',
                   f'More Dem: g={plot_df.hedges_g.abs().max():.3f}'],
    tooltip_columns=['Frequency', 'hedges_g'],
    term_description_columns=['Feature', 'Examples',
                              'hedges_g', 'hedges_g_p', 'Frequency', 'Operationalization'],
    term_description_column_names={'hedges_g': "Hedge's g",
                                   'hedges_g_p': "Hedge's g p-value"},
    header_names={'upper': 'Top Democratic', 'lower': 'Top Republican'},
    term_word_in_term_description='Biber Category',
)

fn = 'demo_biber_category.html'
with open(fn, 'w') as of:
    of.write(html)
print(f'run open ./{fn}')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 html = st.dataframe_scattertext(
#       2     biber_category_corpus,
#       3     plot_df=plot_df,
#       4     category='Dem',
#       5     category_name='Democratic',
#       6     not_category_name='Republican',
#       7     width_in_pixels=1000,
#       8     suppress_text_column='Display',
#       9     metadata=lambda c: c.get_df()['speaker'],
#      10     use_non_text_features=True,
#      11     ignore_categories=False,
#      12     use_offsets=True,
#      13     unified_context=False,
#      14     horizontal_line_y_position=0,
#      15     color_score_column='ColorScore',
#      16     left_list_column='ColorScore',
#      17     y_label='Hedges G',
#      18     x_label='Frequency Ranks',
#      19     y_axis_labels=[f'More Rep: g=-{plot_df.hedges_g.abs().max():.3f}',
#      20                    '0',
#      21                    f'More Dem: g={plot_df.hedges_g.abs().max():.3f}'],
#      22     tooltip_columns=['Frequency', 'hedges_g'],
#      23     term_description_columns=['Feature', 'Examples',
#      24                               'hedges_g', 'hedges_g_p', 'Frequency', 'Operationalization'],
#      25     term_description_column_names={'hedges_g': "Hedge's g",
#      26                                    'hedges_g_p': "Hedge's g p-value"},
#      27     header_names={'upper': 'Top Democratic', 'lower': 'Top Republican'},
#      28     term_word_in_term_description='Biber Category',
#      29 )
#      31 fn = 'demo_biber_category.html'
#      32 with open(fn, 'w') as of:
#
# File ~/anaconda3/envs/py311/lib/python3.11/site-packages/scattertext-0.2.0-py3.11.egg/scattertext/__init__.py:2124, in dataframe_scattertext(corpus, plot_df, **kwargs)
#    2119     print(f"There are {'metadata' if use_metadata else 'terms'} in the corpus which "
#    2120                  f"are not in the index of plot_df. These will not be available in the visualization."
#    2121                  f" These are: {excess_terms}.s")
#    2122     corpus = corpus.remove_terms(terms=excess_terms, non_text=True)
# -> 2124 plot_df = plot_df.reindex(corpus.get_terms(use_metadata=use_metadata))
#    2126 assert len(plot_df) > 0
#    2128 if 'term_description_columns' not in kwargs:
#
# File ~/anaconda3/envs/py311/lib/python3.11/site-packages/pandas/core/frame.py:5063, in DataFrame.reindex(self, labels, index, columns, axis, method, copy, level, fill_value, limit, tolerance)
#    5044 @doc(
#    5045     NDFrame.reindex,
#    5046     klass=_shared_doc_kwargs["klass"],
#    (...)
#    5061     tolerance=None,
#    5062 ) -> DataFrame:
# -> 5063     return super().reindex(
#    5064         labels=labels,
#    5065         index=index,
#    5066         columns=columns,
#    5067         axis=axis,
#    5068         method=method,
#    5069         copy=copy,
#    5070         level=level,
#    5071         fill_value=fill_value,
#    5072         limit=limit,
#    5073         tolerance=tolerance,
#    5074     )
#
# File ~/anaconda3/envs/py311/lib/python3.11/site-packages/pandas/core/generic.py:5360, in NDFrame.reindex(self, labels, index, columns, axis, method, copy, level, fill_value, limit, tolerance)
#    5357     return self._reindex_multi(axes, copy, fill_value)
#    5359 # perform the reindex on the axes
# -> 5360 return self._reindex_axes(
#    5361     axes, level, limit, tolerance, method, fill_value, copy
#    5362 ).__finalize__(self, method="reindex")
#
# File ~/anaconda3/envs/py311/lib/python3.11/site-packages/pandas/core/frame.py:4904, in DataFrame._reindex_axes(self, axes, level, limit, tolerance, method, fill_value, copy)
#    4902 index = axes["index"]
#    4903 if index is not None:
# -> 4904     frame = frame._reindex_index(
#    4905         index, method, copy, level, fill_value, limit, tolerance
#    4906     )
#    4908 return frame
#
# File ~/anaconda3/envs/py311/lib/python3.11/site-packages/pandas/core/frame.py:4920, in DataFrame._reindex_index(self, new_index, method, copy, level, fill_value, limit, tolerance)
#    4910 def _reindex_index(
#    4911     self,
#    4912     new_index,
#    (...)
#    4918     tolerance=None,
#    4919 ):
# -> 4920     new_index, indexer = self.index.reindex(
#    4921         new_index, method=method, level=level, limit=limit, tolerance=tolerance
#    4922     )
#    4923     return self._reindex_with_indexers(
#    4924         {0: [new_index, indexer]},
#    4925         copy=copy,
#    4926         fill_value=fill_value,
#    4927         allow_dups=False,
#    4928     )
#
# File ~/anaconda3/envs/py311/lib/python3.11/site-packages/pandas/core/indexes/base.py:4274, in Index.reindex(self, target, method, level, limit, tolerance)
#    4271     raise ValueError("cannot handle a non-unique multi-index!")
#    4272 elif not self.is_unique:
#    4273     # GH#42568
# -> 4274     raise ValueError("cannot reindex on an axis with duplicate labels")
#    4275 else:
#    4276     indexer, _ = self.get_indexer_non_unique(target)
#
# ValueError: cannot reindex on an axis with duplicate labels

# %%
arglex_corpus = st.OffsetCorpusFactory(
    convention_df,
    category_col='Party',
    parsed_col='Parse',
    feat_and_offset_getter=stvl.get_arglex_offset_getter()
).build(show_progress=True)
# Out:
#   0%|          | 0/189 [00:00<?, ?it/s]

# %%
plot_df = st.HedgesG(
    arglex_corpus
).use_metadata().set_categories(
    category_name='Dem'
).get_score_df(
).assign(
    Frequency=lambda df: df.count1 + df.count2,
    X=lambda df: df.Frequency,
    Y=lambda df: df.hedges_g,
    Xpos=lambda df: st.Scalers.dense_rank(df.X),
    Ypos=lambda df: st.Scalers.scale_center_zero_abs(df.Y),
    ColorScore=lambda df: df.Ypos,
)

plot_df
# Out:
#                     cohens_d  cohens_d_se  cohens_d_z  cohens_d_p  hedges_g
# term
# assessments         0.216977     0.145910    1.487063    0.068499  0.216115  \
# causation          -0.031535     0.145492   -0.216745    0.585797 -0.031409
# conditionals        0.066958     0.145523    0.460121    0.322715  0.066692
# difficulty         -0.041070     0.145498   -0.282272    0.611132 -0.040907
# emphasis            0.494406     0.147689    3.347630    0.000408  0.492442
# inconsistency       0.030399     0.145491    0.208941    0.417247  0.030278
# necessity          -0.065892     0.145522   -0.452800    0.674654 -0.065631
# possibility        -0.326316     0.146448   -2.228212    0.987067 -0.325020
# priority           -0.128791     0.145633   -0.884348    0.811746 -0.128279
# structure           0.201623     0.145852    1.382386    0.083427  0.200822
# wants               0.032797     0.145492    0.225421    0.410826  0.032667
# contrast           -0.361548     0.146666   -2.465107    0.993151 -0.360112
# generalization     -0.184407     0.145792   -1.264868    0.897041 -0.183674
# authority          -0.209395     0.145881   -1.435384    0.924411 -0.208563
# rhetoricalquestion -0.231302     0.145968   -1.584607    0.943472 -0.230383
# doubt              -0.211455     0.145889   -1.449427    0.926391 -0.210615
#
#                     hedges_g_se  hedges_g_z  hedges_g_p        m1        m2
# term
# assessments            0.152437    1.417736    0.078134  0.004899  0.001208  \
# causation              0.151641   -0.207129    0.582046  0.493636  0.499779
# conditionals           0.151702    0.439627    0.330103  0.013423  0.011327
# difficulty             0.151653   -0.269739    0.606319  0.003784  0.004684
# emphasis               0.155798    3.160776    0.000787  0.078903  0.030163
# inconsistency          0.151640    0.199672    0.420869  0.026857  0.025513
# necessity              0.151699   -0.432636    0.667360  0.120420  0.129556
# possibility            0.153456   -2.117996    0.982912  0.057513  0.082285
# priority               0.151911   -0.844434    0.800787  0.055955  0.066609
# structure              0.152326    1.318370    0.093690  0.083742  0.059669
# wants                  0.151643    0.215419    0.414720  0.031698  0.029716
# contrast               0.153870   -2.340361    0.990367  0.021022  0.039297
# generalization         0.152212   -1.206703    0.886227  0.007729  0.013197
# authority              0.152381   -1.368692    0.914452  0.000048  0.005051
# rhetoricalquestion     0.152547   -1.510240    0.934509  0.000370  0.001769
# doubt                  0.152396   -1.382021    0.916517  0.000000  0.000178
#
#                     count1  count2  docs1  docs2  Frequency     X         Y
# term
# assessments             13       3      9      3         16    16  0.216115  \
# causation             1033     793    120     64       1826  1826 -0.031409
# conditionals            29      26     23     17         55    55  0.066692
# difficulty               5      11      5      8         16    16 -0.040907
# emphasis               163      65     72     28        228   228  0.492442
# inconsistency           77      60     41     30        137   137  0.030278
# necessity              309     219     89     47        528   528 -0.065631
# possibility            149     159     63     46        308   308 -0.325020
# priority               112     101     63     39        213   213 -0.128279
# structure              143      84     67     40        227   227  0.200822
# wants                  104      73     36     25        177   177  0.032667
# contrast                61      69     31     31        130   130 -0.360112
# generalization          17      30     14     16         47    47 -0.183674
# authority                1       1      1      1          2     2 -0.208563
# rhetoricalquestion       1       3      1      3          4     4 -0.230383
# doubt                    0       1      0      1          1     1 -0.210615
#
#                         Xpos      Ypos  ColorScore
# term
# assessments         0.214286  0.719432    0.719432
# causation           1.000000  0.468109    0.468109
# conditionals        0.357143  0.567716    0.567716
# difficulty          0.214286  0.458465    0.458465
# emphasis            0.785714  1.000000    1.000000
# inconsistency       0.500000  0.530743    0.530743
# necessity           0.928571  0.433362    0.433362
# possibility         0.857143  0.169992    0.169992
# priority            0.642857  0.369752    0.369752
# structure           0.714286  0.703905    0.703905
# wants               0.571429  0.533168    0.533168
# contrast            0.428571  0.134361    0.134361
# generalization      0.285714  0.313507    0.313507
# authority           0.071429  0.288236    0.288236
# rhetoricalquestion  0.142857  0.266081    0.266081
# doubt               0.000000  0.286153    0.286153

# %%
html = st.dataframe_scattertext(
    arglex_corpus,
    plot_df=plot_df,
    category='Dem',
    category_name='Democratic',
    not_category_name='Republican',
    width_in_pixels=1000,
    suppress_text_column='Display',
    metadata=lambda c: c.get_df()['speaker'],
    use_non_text_features=True,
    ignore_categories=False,
    use_offsets=True,
    unified_context=False,
    horizontal_line_y_position=0,
    color_score_column='ColorScore',
    left_list_column='ColorScore',
    y_label='Hedges G',
    x_label='Frequency Ranks',
    y_axis_labels=[f'More Rep: g=-{plot_df.hedges_g.abs().max():.3f}',
                   '0',
                   f'More Dem: g={plot_df.hedges_g.abs().max():.3f}'],
    tooltip_columns=['Frequency', 'hedges_g'],
    term_description_columns=['hedges_g', 'hedges_g_p', 'Frequency'],
    term_description_column_names={'hedges_g': "Hedge's g",
                                   'hedges_g_p': "Hedge's g p-value"},
    header_names={'upper': 'Top Democratic', 'lower': 'Top Republican'},
    term_word_in_term_description='Arglex Tag',
)

fn = 'demo_arglex.html'
with open(fn, 'w') as of:
    of.write(html)
print(f'run open ./{fn}')
# Out:
# run open ./demo_arglex.html

# %%
# !open ./demo_arglex.html
