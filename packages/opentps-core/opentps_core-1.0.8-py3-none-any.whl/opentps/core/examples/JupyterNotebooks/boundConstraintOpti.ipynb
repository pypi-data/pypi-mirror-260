# %% [markdown]
# ## Bound Constraint Optimization

# %%
import math
import os
import logging
import numpy as np
from matplotlib import pyplot as plt
import sys
sys.path.append('..')


from opentps.core.data.images import CTImage
from opentps.core.data.images import ROIMask
from opentps.core.data.plan import ObjectivesList
from opentps.core.data.plan import PlanDesign
from opentps.core.data import DVH
from opentps.core.data import Patient
from opentps.core.data.plan import FidObjective
from opentps.core.io import mcsquareIO
from opentps.core.io.scannerReader import readScanner
from opentps.core.io.serializedObjectIO import saveRTPlan, loadRTPlan
from opentps.core.processing.doseCalculation.doseCalculationConfig import DoseCalculationConfig
from opentps.core.processing.doseCalculation.mcsquareDoseCalculator import MCsquareDoseCalculator
from opentps.core.processing.imageProcessing.resampler3D import resampleImage3DOnImage3D, resampleImage3D
from opentps.core.processing.planOptimization.planOptimization import BoundConstraintsOptimizer, IMPTPlanOptimizer
logger = logging.getLogger(__name__)
# Out:
# 07/08/2023 03:46:30 PM - root - INFO - Loading logging configuration: /home/romain/opentps/opentps_core/opentps/core/config/logger/logging_config.json
# 07/08/2023 03:46:30 PM - opentps.core._loggingConfig - INFO - Log level set: INFO
# 07/08/2023 03:46:30 PM - opentps.core.processing.imageProcessing.cupyImageProcessing - WARNING - Cannot import Cupy module
# 07/08/2023 03:46:30 PM - opentps.core.processing.registration.registrationMorphons - WARNING - cupy not found.
# 07/08/2023 03:46:30 PM - opentps.core.processing.C_libraries.libInterp3_wrapper - WARNING - cupy not found.
# 07/08/2023 03:46:30 PM - opentps.core.processing.planOptimization.solvers.lp - WARNING - Ignore the following warning if not using Gurobi linear optimizer. Gurobi not required for most features provided in OpenTPS
# 07/08/2023 03:46:30 PM - opentps.core.processing.planOptimization.solvers.lp - WARNING - No module Gurobi found
# !Licence required!
# Get free Academic license on https://www.gurobi.com/academia/academic-program-and-licenses/
# 07/08/2023 03:46:30 PM - numexpr.utils - INFO - Note: NumExpr detected 56 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# 07/08/2023 03:46:30 PM - numexpr.utils - INFO - NumExpr defaulting to 8 threads.

# %% [markdown]
# ### Generic example: Box of water with squared targets

# %%
output_path = os.getcwd()
logger.info('Files will be stored in {}'.format(output_path))

ctCalibration = readScanner(DoseCalculationConfig().scannerFolder)
bdl = mcsquareIO.readBDL(DoseCalculationConfig().bdlFile)

patient = Patient()
patient.name = 'Patient'

ctSize = 150

ct = CTImage()
ct.name = 'CT'
ct.patient = patient


huAir = -1024.
huWater = ctCalibration.convertRSP2HU(1.)
data = huAir * np.ones((ctSize, ctSize, ctSize))
data[:, 50:, :] = huWater
ct.imageArray = data

roi = ROIMask()
roi.patient = patient
roi.name = 'TV'
roi.color = (255, 0, 0) # red
data = np.zeros((ctSize, ctSize, ctSize)).astype(bool)
data[100:120, 100:120, 100:120] = True
roi.imageArray = data
# Out:
# 07/08/2023 03:46:31 PM - __main__ - INFO - Files will be stored in /home/romain/OpenTPS_pycharm_sync/opentps_core/opentps/core/examples/planOptimization

# %% [markdown]
# ### Design plan

# %%
beamNames = ["Beam1"]
gantryAngles = [0.]
couchAngles = [0.]

# method 1 : create or load existing plan (no workflow)

# Configure MCsquare
mc2 = MCsquareDoseCalculator()
mc2.beamModel = bdl
mc2.nbPrimaries = 5e4
mc2.ctCalibration = ctCalibration

# Load / Generate new plan
plan_file = os.path.join(output_path,"Plan_WaterPhantom_cropped_resampled.tps")

if os.path.isfile(plan_file):
    plan = loadRTPlan(plan_file)
    logger.info('Plan loaded')
else:
    planInit = PlanDesign()
    planInit.ct = ct
    planInit.targetMask = roi
    planInit.gantryAngles = gantryAngles
    planInit.beamNames = beamNames
    planInit.couchAngles = couchAngles
    planInit.calibration = ctCalibration
    planInit.spotSpacing = 5.0
    planInit.layerSpacing = 5.0
    planInit.targetMargin = 5.0
    planInit.setScoringParameters(scoringSpacing=[2, 2, 2], adapt_gridSize_to_new_spacing=True)

    plan = planInit.buildPlan()  # Spot placement
    plan.PlanName = "NewPlan"

    beamlets = mc2.computeBeamlets(ct, plan, roi=[roi])
    plan.planDesign.beamlets = beamlets

    beamlets.storeOnFS(os.path.join(output_path, "BeamletMatrix_" + plan.seriesInstanceUID + ".blm"))

    saveRTPlan(plan, plan_file)

plan.planDesign.objectives = ObjectivesList()
plan.planDesign.objectives.setTarget(roi.name, 20.0)
plan.planDesign.objectives.fidObjList = []
plan.planDesign.objectives.addFidObjective(roi, FidObjective.Metrics.DMAX, 20.0, 1.0)
plan.planDesign.objectives.addFidObjective(roi, FidObjective.Metrics.DMIN, 20.0, 1.0)

solver = BoundConstraintsOptimizer(method='Scipy-LBFGS', plan=plan, maxit=50, bounds=(0.2, 50))

# Optimize treatment plan
w, doseImage, ps = solver.optimize()

# Compute DVH on resampled contour
target_DVH = DVH(roi, doseImage)
print('D95 = ' + str(target_DVH.D95) + ' Gy')
print('D5 = ' + str(target_DVH.D5) + ' Gy')
print('D5 - D95 =  {} Gy'.format(target_DVH.D5 - target_DVH.D95))

# center of mass
roi = resampleImage3DOnImage3D(roi, ct)
COM_coord = roi.centerOfMass
COM_index = roi.getVoxelIndexFromPosition(COM_coord)
Z_coord = COM_index[2]
# Out:
# /home/romain/OpenTPS_pycharm_sync/opentps_core/opentps/core/examples/planOptimization/Plan_WaterPhantom_cropped_resampled.tps
# 07/08/2023 03:46:43 PM - __main__ - INFO - Plan loaded
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =          317     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  5.91371D+01    |proj g|=  8.39882D-01
# 07/08/2023 03:46:43 PM - opentps.core.processing.planOptimization.solvers.bfgs - INFO - Iteration 1 of Scipy-L-BFGS-B
#
# At iterate    1    f=  4.08013D+01    |proj g|=  6.53462D-01
# 07/08/2023 03:46:43 PM - opentps.core.processing.planOptimization.solvers.bfgs - INFO - objective = 4.080134e+01
# 07/08/2023 03:46:43 PM - opentps.core.processing.planOptimization.solvers.bfgs - INFO - Iteration 2 of Scipy-L-BFGS-B
#
# At iterate    2    f=  1.01520D+01    |proj g|=  1.97161D-01
# 07/08/2023 03:46:43 PM - opentps.core.processing.planOptimization.solvers.bfgs - INFO - objective = 1.015204e+01
# 07/08/2023 03:46:43 PM - opentps.core.processing.planOptimization.solvers.bfgs - INFO - Iteration 3 of Scipy-L-BFGS-B
#
# At iterate    3    f=  7.25887D+00    |proj g|=  1.69063D-01
# 07/08/2023 03:46:43 PM - opentps.core.processing.planOptimization.solvers.bfgs - INFO - objective = 7.258872e+00
# 07/08/2023 03:46:43 PM - opentps.core.processing.planOptimization.solvers.bfgs - INFO - Iteration 4 of Scipy-L-BFGS-B
#
# At iterate    4    f=  2.47085D+00    |proj g|=  6.80004D-02
# 07/08/2023 03:46:43 PM - opentps.core.processing.planOptimization.solvers.bfgs - INFO - objective = 2.470851e+00
# 07/08/2023 03:46:43 PM - opentps.core.processing.planOptimization.solvers.bfgs - INFO - Iteration 5 of Scipy-L-BFGS-B
#
# At iterate    5    f=  1.73324D+00    |proj g|=  4.54827D-02
# 07/08/2023 03:46:43 PM - opentps.core.processing.planOptimization.solvers.bfgs - INFO - objective = 1.733244e+00
# 07/08/2023 03:46:43 PM - opentps.core.processing.planOptimization.solvers.bfgs - INFO - Iteration 6 of Scipy-L-BFGS-B
#
# At iterate    6    f=  1.24347D+00    |proj g|=  2.55842D-02
# 07/08/2023 03:46:43 PM - opentps.core.processing.planOptimization.solvers.bfgs - INFO - objective = 1.243471e+00
# 07/08/2023 03:46:43 PM - opentps.core.processing.planOptimization.solvers.bfgs - INFO - Iteration 7 of Scipy-L-BFGS-B
#
# At iterate    7    f=  1.14364D+00    |proj g|=  1.63272D-02
# 07/08/2023 03:46:43 PM - opentps.core.processing.planOptimization.solvers.bfgs - INFO - objective = 1.143640e+00
# 07/08/2023 03:46:43 PM - opentps.core.processing.planOptimization.solvers.bfgs - INFO - Iteration 8 of Scipy-L-BFGS-B
#
# At iterate    8    f=  1.10201D+00    |proj g|=  1.49829D-02
# 07/08/2023 03:46:43 PM - opentps.core.processing.planOptimization.solvers.bfgs - INFO - objective = 1.102013e+00
# 07/08/2023 03:46:43 PM - opentps.core.processing.planOptimization.solvers.bfgs - INFO - Iteration 9 of Scipy-L-BFGS-B
# At iterate    9    f=  9.21765D-01    |proj g|=  7.53407D-03
# 07/08/2023 03:46:43 PM - opentps.core.processing.planOptimization.solvers.bfgs - INFO - objective = 9.217645e-01
# 07/08/2023 03:46:43 PM - opentps.core.processing.planOptimization.solvers.bfgs - INFO - Iteration 10 of Scipy-L-BFGS-B
#
# At iterate   10    f=  8.78549D-01    |proj g|=  1.56632D-02
# 07/08/2023 03:46:43 PM - opentps.core.processing.planOptimization.solvers.bfgs - INFO - objective = 8.785486e-01
# 07/08/2023 03:46:43 PM - opentps.core.processing.planOptimization.solvers.bfgs - INFO - Iteration 11 of Scipy-L-BFGS-B
#
# At iterate   11    f=  8.36282D-01    |proj g|=  4.53763D-03
# 07/08/2023 03:46:43 PM - opentps.core.processing.planOptimization.solvers.bfgs - INFO - objective = 8.362819e-01
# 07/08/2023 03:46:43 PM - opentps.core.processing.planOptimization.solvers.bfgs - INFO - Iteration 12 of Scipy-L-BFGS-B
#
# At iterate   12    f=  8.28979D-01    |proj g|=  3.27382D-03
# 07/08/2023 03:46:43 PM - opentps.core.processing.planOptimization.solvers.bfgs - INFO - objective = 8.289786e-01
# 07/08/2023 03:46:43 PM - opentps.core.processing.planOptimization.solvers.bfgs - INFO - Iteration 13 of Scipy-L-BFGS-B
#
# At iterate   13    f=  8.14050D-01    |proj g|=  7.84494D-03
# 07/08/2023 03:46:43 PM - opentps.core.processing.planOptimization.solvers.bfgs - INFO - objective = 8.140497e-01
# 07/08/2023 03:46:43 PM - opentps.core.processing.planOptimization.solvers.bfgs - INFO - Iteration 14 of Scipy-L-BFGS-B
#
# At iterate   14    f=  7.98919D-01    |proj g|=  1.72890D-02
# 07/08/2023 03:46:43 PM - opentps.core.processing.planOptimization.solvers.bfgs - INFO - objective = 7.989188e-01
# 07/08/2023 03:46:43 PM - opentps.core.processing.planOptimization.solvers.bfgs - INFO - Iteration 15 of Scipy-L-BFGS-B
#
# At iterate   15    f=  7.75198D-01    |proj g|=  9.56099D-03
# 07/08/2023 03:46:43 PM - opentps.core.processing.planOptimization.solvers.bfgs - INFO - objective = 7.751981e-01
# 07/08/2023 03:46:43 PM - opentps.core.processing.planOptimization.solvers.bfgs - INFO - Iteration 16 of Scipy-L-BFGS-B
#
# At iterate   16    f=  7.46523D-01    |proj g|=  6.67393D-03
# 07/08/2023 03:46:43 PM - opentps.core.processing.planOptimization.solvers.bfgs - INFO - objective = 7.465231e-01
# 07/08/2023 03:46:43 PM - opentps.core.processing.planOptimization.solvers.bfgs - INFO - Iteration 17 of Scipy-L-BFGS-B
#
# At iterate   17    f=  7.37794D-01    |proj g|=  4.43736D-03
# 07/08/2023 03:46:43 PM - opentps.core.processing.planOptimization.solvers.bfgs - INFO - objective = 7.377939e-01
# 07/08/2023 03:46:43 PM - opentps.core.processing.planOptimization.solvers.bfgs - INFO - Iteration 18 of Scipy-L-BFGS-B
#
# At iterate   18    f=  7.25331D-01    |proj g|=  3.41743D-03
# 07/08/2023 03:46:43 PM - opentps.core.processing.planOptimization.solvers.bfgs - INFO - objective = 7.253312e-01
# 07/08/2023 03:46:43 PM - opentps.core.processing.planOptimization.solvers.bfgs - INFO - Iteration 19 of Scipy-L-BFGS-B
#
# At iterate   19    f=  7.06128D-01    |proj g|=  6.18407D-03
# 07/08/2023 03:46:43 PM - opentps.core.processing.planOptimization.solvers.bfgs - INFO - objective = 7.061284e-01
# 07/08/2023 03:46:43 PM - opentps.core.processing.planOptimization.solvers.bfgs - INFO - Iteration 20 of Scipy-L-BFGS-B
#
# At iterate   20    f=  6.84715D-01    |proj g|=  8.06154D-03
# 07/08/2023 03:46:43 PM - opentps.core.processing.planOptimization.solvers.bfgs - INFO - objective = 6.847150e-01
# 07/08/2023 03:46:43 PM - opentps.core.processing.planOptimization.solvers.bfgs - INFO - Iteration 21 of Scipy-L-BFGS-B
#
# At iterate   21    f=  6.56739D-01    |proj g|=  1.32800D-02
# 07/08/2023 03:46:43 PM - opentps.core.processing.planOptimization.solvers.bfgs - INFO - objective = 6.567390e-01
# 07/08/2023 03:46:43 PM - opentps.core.processing.planOptimization.solvers.bfgs - INFO - Iteration 22 of Scipy-L-BFGS-B
#
# At iterate   22    f=  6.36235D-01    |proj g|=  9.11510D-03
# 07/08/2023 03:46:43 PM - opentps.core.processing.planOptimization.solvers.bfgs - INFO - objective = 6.362353e-01
# 07/08/2023 03:46:43 PM - opentps.core.processing.planOptimization.solvers.bfgs - INFO - Iteration 23 of Scipy-L-BFGS-B
#
# At iterate   23    f=  6.23726D-01    |proj g|=  4.21993D-03
# 07/08/2023 03:46:43 PM - opentps.core.processing.planOptimization.solvers.bfgs - INFO - objective = 6.237260e-01
# 07/08/2023 03:46:43 PM - opentps.core.processing.planOptimization.solvers.bfgs - INFO - Iteration 24 of Scipy-L-BFGS-B
#
# At iterate   24    f=  6.16395D-01    |proj g|=  4.52465D-03
# 07/08/2023 03:46:43 PM - opentps.core.processing.planOptimization.solvers.bfgs - INFO - objective = 6.163947e-01
# 07/08/2023 03:46:43 PM - opentps.core.processing.planOptimization.solvers.bfgs - INFO - Iteration 25 of Scipy-L-BFGS-B
#
# At iterate   25    f=  6.10798D-01    |proj g|=  5.35422D-03
# 07/08/2023 03:46:43 PM - opentps.core.processing.planOptimization.solvers.bfgs - INFO - objective = 6.107981e-01
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#   317     25     27     25     0     2   5.354D-03   6.108D-01
#   F =  0.61079809069633484
#
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =          307     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  6.11102D-01    |proj g|=  5.80711D-03
# 07/08/2023 03:46:43 PM - opentps.core.processing.planOptimization.solvers.bfgs - INFO - Iteration 26 of Scipy-L-BFGS-B
#
# At iterate    1    f=  6.10258D-01    |proj g|=  5.18212D-03
# 07/08/2023 03:46:43 PM - opentps.core.processing.planOptimization.solvers.bfgs - INFO - objective = 6.102576e-01
# 07/08/2023 03:46:43 PM - opentps.core.processing.planOptimization.solvers.bfgs - INFO - Iteration 27 of Scipy-L-BFGS-B
#
# At iterate    2    f=  6.06640D-01    |proj g|=  4.27661D-03
# 07/08/2023 03:46:43 PM - opentps.core.processing.planOptimization.solvers.bfgs - INFO - objective = 6.066398e-01
# 07/08/2023 03:46:43 PM - opentps.core.processing.planOptimization.solvers.bfgs - INFO - Iteration 28 of Scipy-L-BFGS-B
#
# At iterate    3    f=  6.04592D-01    |proj g|=  4.98445D-03
# 07/08/2023 03:46:43 PM - opentps.core.processing.planOptimization.solvers.bfgs - INFO - objective = 6.045925e-01
# 07/08/2023 03:46:43 PM - opentps.core.processing.planOptimization.solvers.bfgs - INFO - Iteration 29 of Scipy-L-BFGS-B
#
# At iterate    4    f=  5.98598D-01    |proj g|=  5.04751D-03
# 07/08/2023 03:46:43 PM - opentps.core.processing.planOptimization.solvers.bfgs - INFO - objective = 5.985982e-01
# 07/08/2023 03:46:43 PM - opentps.core.processing.planOptimization.solvers.bfgs - INFO - Iteration 30 of Scipy-L-BFGS-B
#
# At iterate    5    f=  5.90898D-01    |proj g|=  5.82026D-03
# 07/08/2023 03:46:43 PM - opentps.core.processing.planOptimization.solvers.bfgs - INFO - objective = 5.908978e-01
# 07/08/2023 03:46:43 PM - opentps.core.processing.planOptimization.solvers.bfgs - INFO - Iteration 31 of Scipy-L-BFGS-B
#
# At iterate    6    f=  5.84331D-01    |proj g|=  9.54297D-03
# 07/08/2023 03:46:43 PM - opentps.core.processing.planOptimization.solvers.bfgs - INFO - objective = 5.843312e-01
# 07/08/2023 03:46:43 PM - opentps.core.processing.planOptimization.solvers.bfgs - INFO - Iteration 32 of Scipy-L-BFGS-B
#
# At iterate    7    f=  5.73875D-01    |proj g|=  2.80360D-03
# 07/08/2023 03:46:43 PM - opentps.core.processing.planOptimization.solvers.bfgs - INFO - objective = 5.738746e-01
# 07/08/2023 03:46:43 PM - opentps.core.processing.planOptimization.solvers.bfgs - INFO - Iteration 33 of Scipy-L-BFGS-B
#
# At iterate    8    f=  5.70551D-01    |proj g|=  1.88870D-03
# 07/08/2023 03:46:43 PM - opentps.core.processing.planOptimization.solvers.bfgs - INFO - objective = 5.705511e-01
# 07/08/2023 03:46:43 PM - opentps.core.processing.planOptimization.solvers.bfgs - INFO - Iteration 34 of Scipy-L-BFGS-B
#
# At iterate    9    f=  5.67914D-01    |proj g|=  1.44897D-03
# 07/08/2023 03:46:43 PM - opentps.core.processing.planOptimization.solvers.bfgs - INFO - objective = 5.679142e-01
# 07/08/2023 03:46:43 PM - opentps.core.processing.planOptimization.solvers.bfgs - INFO - Iteration 35 of Scipy-L-BFGS-B
#
# At iterate   10    f=  5.63776D-01    |proj g|=  1.75621D-03
# 07/08/2023 03:46:43 PM - opentps.core.processing.planOptimization.solvers.bfgs - INFO - objective = 5.637760e-01
# 07/08/2023 03:46:43 PM - opentps.core.processing.planOptimization.solvers.bfgs - INFO - Iteration 36 of Scipy-L-BFGS-B
#
# At iterate   11    f=  5.61044D-01    |proj g|=  4.81060D-03
# 07/08/2023 03:46:43 PM - opentps.core.processing.planOptimization.solvers.bfgs - INFO - objective = 5.610441e-01
# 07/08/2023 03:46:43 PM - opentps.core.processing.planOptimization.solvers.bfgs - INFO - Iteration 37 of Scipy-L-BFGS-B
#
# At iterate   12    f=  5.54987D-01    |proj g|=  2.19499D-03
# 07/08/2023 03:46:43 PM - opentps.core.processing.planOptimization.solvers.bfgs - INFO - objective = 5.549866e-01
# 07/08/2023 03:46:43 PM - opentps.core.processing.planOptimization.solvers.bfgs - INFO - Iteration 38 of Scipy-L-BFGS-B
#
# At iterate   13    f=  5.52667D-01    |proj g|=  1.50084D-03
# 07/08/2023 03:46:43 PM - opentps.core.processing.planOptimization.solvers.bfgs - INFO - objective = 5.526672e-01
# 07/08/2023 03:46:43 PM - opentps.core.processing.planOptimization.solvers.bfgs - INFO - Iteration 39 of Scipy-L-BFGS-B
#
# At iterate   14    f=  5.50259D-01    |proj g|=  3.52973D-03
# 07/08/2023 03:46:43 PM - opentps.core.processing.planOptimization.solvers.bfgs - INFO - objective = 5.502590e-01
# 07/08/2023 03:46:43 PM - opentps.core.processing.planOptimization.solvers.bfgs - INFO - Iteration 40 of Scipy-L-BFGS-B
#
# At iterate   15    f=  5.48882D-01    |proj g|=  3.71244D-03
# 07/08/2023 03:46:43 PM - opentps.core.processing.planOptimization.solvers.bfgs - INFO - objective = 5.488818e-01
# 07/08/2023 03:46:43 PM - opentps.core.processing.planOptimization.solvers.bfgs - INFO - Iteration 41 of Scipy-L-BFGS-B
#
# At iterate   16    f=  5.46985D-01    |proj g|=  1.53606D-03
# 07/08/2023 03:46:43 PM - opentps.core.processing.planOptimization.solvers.bfgs - INFO - objective = 5.469852e-01
# 07/08/2023 03:46:43 PM - opentps.core.processing.planOptimization.solvers.bfgs - INFO - Iteration 42 of Scipy-L-BFGS-B
#
# At iterate   17    f=  5.44408D-01    |proj g|=  2.49495D-03
# 07/08/2023 03:46:43 PM - opentps.core.processing.planOptimization.solvers.bfgs - INFO - objective = 5.444079e-01
# 07/08/2023 03:46:43 PM - opentps.core.processing.planOptimization.solvers.bfgs - INFO - Iteration 43 of Scipy-L-BFGS-B
#
# At iterate   18    f=  5.41911D-01    |proj g|=  2.82220D-03
# 07/08/2023 03:46:43 PM - opentps.core.processing.planOptimization.solvers.bfgs - INFO - objective = 5.419112e-01
# 07/08/2023 03:46:43 PM - opentps.core.processing.planOptimization.solvers.bfgs - INFO - Iteration 44 of Scipy-L-BFGS-B
#
# At iterate   19    f=  5.36724D-01    |proj g|=  3.63221D-03
# 07/08/2023 03:46:43 PM - opentps.core.processing.planOptimization.solvers.bfgs - INFO - objective = 5.367237e-01
# 07/08/2023 03:46:43 PM - opentps.core.processing.planOptimization.solvers.bfgs - INFO - Iteration 45 of Scipy-L-BFGS-B
#
# At iterate   20    f=  5.31711D-01    |proj g|=  4.93550D-03
# 07/08/2023 03:46:43 PM - opentps.core.processing.planOptimization.solvers.bfgs - INFO - objective = 5.317112e-01
# 07/08/2023 03:46:43 PM - opentps.core.processing.planOptimization.solvers.bfgs - INFO - Iteration 46 of Scipy-L-BFGS-B
#
# At iterate   21    f=  5.25063D-01    |proj g|=  3.71629D-03
# 07/08/2023 03:46:43 PM - opentps.core.processing.planOptimization.solvers.bfgs - INFO - objective = 5.250625e-01
# 07/08/2023 03:46:43 PM - opentps.core.processing.planOptimization.solvers.bfgs - INFO - Iteration 47 of Scipy-L-BFGS-B
#
# At iterate   22    f=  5.19339D-01    |proj g|=  2.78253D-03
# 07/08/2023 03:46:43 PM - opentps.core.processing.planOptimization.solvers.bfgs - INFO - objective = 5.193388e-01
# 07/08/2023 03:46:43 PM - opentps.core.processing.planOptimization.solvers.bfgs - INFO - Iteration 48 of Scipy-L-BFGS-B
#
# At iterate   23    f=  5.11058D-01    |proj g|=  4.09310D-03
# 07/08/2023 03:46:43 PM - opentps.core.processing.planOptimization.solvers.bfgs - INFO - objective = 5.110576e-01
# 07/08/2023 03:46:43 PM - opentps.core.processing.planOptimization.solvers.bfgs - INFO - Iteration 49 of Scipy-L-BFGS-B
#
# At iterate   24    f=  5.07512D-01    |proj g|=  3.73476D-03
# 07/08/2023 03:46:43 PM - opentps.core.processing.planOptimization.solvers.bfgs - INFO - objective = 5.075122e-01
# 07/08/2023 03:46:43 PM - opentps.core.processing.planOptimization.solvers.bfgs - INFO - Iteration 50 of Scipy-L-BFGS-B
#
# At iterate   25    f=  5.03874D-01    |proj g|=  1.66091D-03
# 07/08/2023 03:46:43 PM - opentps.core.processing.planOptimization.solvers.bfgs - INFO - objective = 5.038742e-01
# 07/08/2023 03:46:43 PM - opentps.core.processing.planOptimization.planOptimization - INFO -  ScipyOpt terminated in 25 Iter, x = [16.838718   16.32364    14.318677   11.275313   12.680151    9.344168
#   6.224605    8.769085    5.812803   11.362295    9.919434   14.190114
#   3.5004148  13.3889675  10.844087    8.751568    6.4012017   9.92223
#  13.880263    9.445315   11.370461   17.885689    8.297433    9.194516
#  10.0998955  12.8275175   7.1719074   4.2631607  10.224802    8.00287
#   9.553234    9.947708    9.317878   10.114211    9.519372    9.486824
#   8.902139    9.88824     6.593863    7.373212    8.124228    6.9438405
#  19.775734   12.232585   16.94164    12.43257    10.715368    7.220996
#   0.2         8.008598    0.22836216 11.11726    10.17636    11.345683
#   0.2         3.5498664   0.34787145  2.7115605   1.5788392   7.93543
#  11.972766    3.1571755   0.5182696   8.869162    0.2         7.410723
#   9.861441   12.837082    0.75725615  1.7897556   1.3198175   2.4020743
#   3.7983963  10.255119   11.696704    7.079866    9.626166    7.9844003
#   6.9222617   8.695852    8.762406    9.099338    7.2762933   7.763247
#  11.744659    9.309141   11.37194     6.985714    2.4413724   4.2609243
#   0.          3.3182201   0.          4.0917087   4.204933    8.578845
#   0.          3.6361952   0.8860714   2.488573    0.48117015  7.0219855
#   8.75638     0.3722405   1.859954    7.53703     1.9027005   2.646904
#   9.028899    6.130256    0.37828925  0.          2.5306728   0.4283175
#   0.30556062  5.150152    6.5744295   2.0987823   5.5043726   3.367901
#   5.7109756   1.7515025   6.686752    6.204209    5.883013    5.9979186
#   8.457121    8.340101    5.765933    6.3219833   3.6152902   0.98406535
#   0.          4.311729    1.184054    2.1736743   4.418304    7.316447
#   0.          1.0237634   1.0847285   0.2         0.2         6.8455677
#   6.3941264   0.37687886  0.2581077   8.487282    0.73916376  1.9126388
#   5.3105006   3.7970977   0.41919926  0.          2.8501534   0.2
#   0.2         4.0797753   5.038278    2.4227934   4.5839834   3.0234058
#   5.0586953   1.5446122   4.328643    4.841639    6.7845435   4.6686344
#   6.530386    5.201107    4.975207    4.3533154   3.2709036   1.6358848
#   0.          2.733981    0.          1.8089406   3.5091493   3.4099932
#   0.          1.9741043   0.2         1.8172516   0.2         4.529056
#   5.855171    0.7279718   0.8008782   3.830594    0.2         0.82190156
#   4.3017993   3.9581769   0.2         0.3596927   1.7112539   0.2
#   1.239676    3.4114144   4.116888    0.8656094   2.5458624   2.8708363
#   2.3944666   1.2306616   3.9222586   3.2690995   3.8040712   3.1479902
#   5.285934    7.785119    7.235876    4.5118766   6.8248196   8.145823
#  11.042029    9.824534   10.250077    6.972462    5.7087793   7.735559
#  10.309451   12.8290615  12.970251   12.3024025   8.8558855   6.16621
#   7.552686   10.826312   12.188804   13.243981   11.183892    9.135316
#   6.158055    6.246288    9.390735    9.633533   11.463361    8.942269
#   8.202995    5.156032    4.413366    6.551122    5.8385153   7.8547807
#   5.6060796   6.037219    4.075151    4.087191    4.5448394   4.0519624
#   3.1242847   3.1242847   3.1242847   3.1242847   3.1242847   3.1242847
#   3.1242847   3.1242847   3.1242847   3.1242847   3.1242847   3.1242847
#   3.1242847   3.1242847   3.1242847   3.1242847   3.1242847   3.1242847
#   3.1242847   3.1242847   3.1242847   3.1242847   3.1242847   3.1242847
#   3.1242847   3.1242847   3.1242847   3.1242847   3.1242847   3.1242847
#   3.1242847   3.1242847   3.1242847   3.1242847   3.1242847   3.1242847
#   3.1242847   3.1242847   3.1242847   3.1242847   3.1242847   3.1242847
#   3.1242847   3.1242847   3.1242847   3.1242847   3.1242847   3.1242847
#   3.1242847   3.1242847   3.1242847   3.1242847   3.1242847   3.1242847
#   3.1242847   3.1242847   3.1242847   3.1242847   3.1242847   3.1242847
#   3.1242847   3.1242847   3.1242847   3.1242847   3.1242847 ], f(x) = [0.6111024022102356, 0.610257625579834, 0.6066397726535797, 0.6045924723148346, 0.5985981523990631, 0.5908977687358856, 0.5843312442302704, 0.5738745629787445, 0.5705510675907135, 0.5679141879081726, 0.5637759864330292, 0.5610440671443939, 0.5549865663051605, 0.5526671707630157, 0.5502589643001556, 0.5488817989826202, 0.5469852387905121, 0.5444079339504242, 0.541911244392395, 0.5367237329483032, 0.5317111611366272, 0.5250625312328339, 0.5193387866020203, 0.511057585477829, 0.5075121968984604, 0.5038741827011108], time elapsed 0.3332846164703369, time per iter 0.013331384658813476
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#   307     25     26     30     0     8   1.661D-03   5.039D-01
#   F =  0.50387418270111084
#
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
# 07/08/2023 03:46:43 PM - opentps.core.processing.planOptimization.planOptimization - INFO - Total dose calculation ...
# 07/08/2023 03:46:43 PM - opentps.core.processing.planOptimization.planOptimization - INFO - Optimization done.
# D95 = 18.84940011160714 Gy
# D5 = 21.05712890625 Gy
# D5 - D95 =  2.207728794642861 Gy

# %% [markdown]
# ### Display dose

# %%
img_ct = ct.imageArray[:, :, Z_coord].transpose(1, 0)
contourTargetMask = roi.getBinaryContourMask()
img_mask = contourTargetMask.imageArray[:, :, Z_coord].transpose(1, 0)
img_dose = resampleImage3DOnImage3D(doseImage, ct)
img_dose = img_dose.imageArray[:, :, Z_coord].transpose(1, 0)

# Display dose
fig, ax = plt.subplots(1, 2, figsize=(12, 5))
#ax[0].axes.get_xaxis().set_visible(False)
#ax[0].axes.get_yaxis().set_visible(False)
ax[0].imshow(img_ct, cmap='gray')
ax[0].imshow(img_mask, alpha=.2, cmap='binary')  # PTV
dose = ax[0].imshow(img_dose, cmap='jet', alpha=.2)
plt.colorbar(dose, ax=ax[0])
ax[1].plot(target_DVH.histogram[0], target_DVH.histogram[1], label=target_DVH.name)
ax[1].set_xlabel("Dose (Gy)")
ax[1].set_ylabel("Volume (%)")
plt.grid(True)
plt.legend()

plt.show()
# Out:
# 07/08/2023 03:46:44 PM - opentps.core.processing.imageProcessing.roiMasksProcessing - INFO - Using SITK to dilate mask.
