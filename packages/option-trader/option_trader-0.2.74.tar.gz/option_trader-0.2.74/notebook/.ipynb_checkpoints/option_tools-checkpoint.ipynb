# %% [markdown]
# https://www.geeksforgeeks.org/microsoft-stock-price-prediction-with-machine-learning/

# %%
from datetime import datetime
import tensorflow as tf
from tensorflow import keras
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
import numpy as np
import seaborn as sns

# %%
import sys

sys.path.append(r'\Users\jimhu\option_trader\src')
from tradingBot.utils.optionTool import delta_call
from tradingBot.utils.optionTool import delta_put
from tradingBot.utils.optionTool import time_to_maturity_in_year
from tradingBot.utils.dataGetter import get_multiple_option_chains
from tradingBot.utils.dataGetter import get_option_exp_date
from tradingBot.utils.dataGetter import get_price_history

from datetime import time, date, datetime, timedelta
from pytz import timezone

from tradingBot.settings.tradeConfig import entryCrit
from tradingBot.settings.tradeConfig import runtimeConfig
from tradingBot.utils.dataGetter import get_price_history
from tradingBot.utils.dataGetter import get_option_exp_date
from tradingBot.consts import asset as at
from tradingBot.excel import positionSheet as ps

# %%
symbol = 'SPY'
period = '30y'
interval = '1d'

df = get_price_history(symbol, period=period, interval=interval)

df
# Out:
#                                  Open        High         Low       Close
# Date
# 1993-05-25 00:00:00-04:00   25.923192   25.923192   25.869335   25.869335  \
# 1993-05-26 00:00:00-04:00   25.941138   26.210423   25.923185   26.192471
# 1993-05-27 00:00:00-04:00   26.228364   26.228364   26.066793   26.102697
# 1993-05-28 00:00:00-04:00   26.084753   26.084753   25.851373   25.977039
# 1993-06-01 00:00:00-04:00   26.066809   26.318142   26.030904   26.228380
# ...                               ...         ...         ...         ...
# 2023-05-18 00:00:00-04:00  414.899994  419.670013  414.670013  419.230011
# 2023-05-19 00:00:00-04:00  420.170013  420.720001  417.350006  418.619995
# 2023-05-22 00:00:00-04:00  418.640015  420.390015  417.350006  418.790009
# 2023-05-23 00:00:00-04:00  417.079987  418.720001  413.679993  414.089996
# 2023-05-24 00:00:00-04:00  412.420013  412.820007  409.880005  411.089996
#
#                               Volume  Dividends  Stock Splits  Capital Gains
# Date
# 1993-05-25 00:00:00-04:00     191800        0.0           0.0            0.0
# 1993-05-26 00:00:00-04:00     102400        0.0           0.0            0.0
# 1993-05-27 00:00:00-04:00      53800        0.0           0.0            0.0
# 1993-05-28 00:00:00-04:00      79100        0.0           0.0            0.0
# 1993-06-01 00:00:00-04:00      28300        0.0           0.0            0.0
# ...                              ...        ...           ...            ...
# 2023-05-18 00:00:00-04:00   97177200        0.0           0.0            0.0
# 2023-05-19 00:00:00-04:00  103679700        0.0           0.0            0.0
# 2023-05-22 00:00:00-04:00   60745400        0.0           0.0            0.0
# 2023-05-23 00:00:00-04:00   86383500        0.0           0.0            0.0
# 2023-05-24 00:00:00-04:00   88801600        0.0           0.0            0.0
#
# [7555 rows x 8 columns]

# %%
symbol = 'MSFT'

calls, puts = get_multiple_option_chains(symbol)

calls
# Out:
#     strike  lastPrice  bid  ask  volume  openInterest  impliedVolatility
# 0    150.0     130.35  0.0  0.0     2.0             0           0.000010  \
# 1    220.0      59.40  0.0  0.0     2.0             0           0.000010
# 2    230.0      82.65  0.0  0.0     NaN             0           0.000010
# 3    240.0      75.00  0.0  0.0     2.0             0           0.000010
# 4    245.0      76.87  0.0  0.0     1.0             0           0.000010
# ..     ...        ...  ...  ...     ...           ...                ...
# 57   415.0       0.15  0.0  0.0    39.0             0           0.125009
# 58   420.0       0.14  0.0  0.0    13.0             0           0.125009
# 59   435.0       0.07  0.0  0.0    60.0             0           0.125009
# 60   440.0       0.03  0.0  0.0     NaN             0           0.125009
# 61   445.0       0.05  0.0  0.0    22.0             0           0.125009
#
#       exp_date  bidSize  askSize  open  high  low  close  delta  gamma  vega
# 0   2023-06-02      NaN      NaN   NaN   NaN  NaN    NaN    1.0    NaN   NaN  \
# 1   2023-06-02      NaN      NaN   NaN   NaN  NaN    NaN    1.0    NaN   NaN
# 2   2023-06-02      NaN      NaN   NaN   NaN  NaN    NaN    1.0    NaN   NaN
# 3   2023-06-02      NaN      NaN   NaN   NaN  NaN    NaN    1.0    NaN   NaN
# 4   2023-06-02      NaN      NaN   NaN   NaN  NaN    NaN    1.0    NaN   NaN
# ..         ...      ...      ...   ...   ...  ...    ...    ...    ...   ...
# 57  2023-08-18      NaN      NaN   NaN   NaN  NaN    NaN    1.0    NaN   NaN
# 58  2023-08-18      NaN      NaN   NaN   NaN  NaN    NaN    1.0    NaN   NaN
# 59  2023-08-18      NaN      NaN   NaN   NaN  NaN    NaN    1.0    NaN   NaN
# 60  2023-08-18      NaN      NaN   NaN   NaN  NaN    NaN    1.0    NaN   NaN
# 61  2023-08-18      NaN      NaN   NaN   NaN  NaN    NaN    1.0    NaN   NaN
#
#     theta  sigma
# 0     NaN    NaN
# 1     NaN    NaN
# 2     NaN    NaN
# 3     NaN    NaN
# 4     NaN    NaN
# ..    ...    ...
# 57    NaN    NaN
# 58    NaN    NaN
# 59    NaN    NaN
# 60    NaN    NaN
# 61    NaN    NaN
#
# [333 rows x 19 columns]

# %%
current_price = df['Close'].tail(1)

# %%
calls['price'] = (calls['bid'] + calls['ask']) / 2
puts['price'] = (puts['bid'] + puts['ask']) / 2

# %%
expected_price = float(current_price.values[0]) - 10

print('expected price', expected_price)

calls['gain'] = calls.apply(lambda x: -x['price'] if x['strike'] > expected_price else 100 * (expected_price-x['strike']-x['price'])/x['price'], axis = 1)

puts['gain'] = puts.apply(lambda x: -x['price'] if expected_price > x['strike']  else 100 * (x['strike'] - expected_price - x['price'])/x['price'], axis = 1)
# Out:
# expected price 401.0899963378906
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[11], line 5
#       1 expected_price = float(current_price.values[0]) - 10
#       3 print('expected price', expected_price)
# ----> 5 calls['gain'] = calls.apply(lambda x: -x['price'] if x['strike'] > expected_price else 100 * (expected_price-x['strike']-x['price'])/x['price'], axis = 1)
#       7 puts['gain'] = puts.apply(lambda x: -x['price'] if expected_price > x['strike']  else 100 * (x['strike'] - expected_price - x['price'])/x['price'], axis = 1)
#
# File C:\ProgramData\Anaconda3\envs\option_trader\Lib\site-packages\pandas\core\frame.py:9433, in DataFrame.apply(self, func, axis, raw, result_type, args, **kwargs)
#    9422 from pandas.core.apply import frame_apply
#    9424 op = frame_apply(
#    9425     self,
#    9426     func=func,
#    (...)
#    9431     kwargs=kwargs,
#    9432 )
# -> 9433 return op.apply().__finalize__(self, method="apply")
#
# File C:\ProgramData\Anaconda3\envs\option_trader\Lib\site-packages\pandas\core\apply.py:678, in FrameApply.apply(self)
#     675 elif self.raw:
#     676     return self.apply_raw()
# --> 678 return self.apply_standard()
#
# File C:\ProgramData\Anaconda3\envs\option_trader\Lib\site-packages\pandas\core\apply.py:798, in FrameApply.apply_standard(self)
#     797 def apply_standard(self):
# --> 798     results, res_index = self.apply_series_generator()
#     800     # wrap results
#     801     return self.wrap_results(results, res_index)
#
# File C:\ProgramData\Anaconda3\envs\option_trader\Lib\site-packages\pandas\core\apply.py:814, in FrameApply.apply_series_generator(self)
#     811 with option_context("mode.chained_assignment", None):
#     812     for i, v in enumerate(series_gen):
#     813         # ignore SettingWithCopy here in case the user mutates
# --> 814         results[i] = self.f(v)
#     815         if isinstance(results[i], ABCSeries):
#     816             # If we have a view on v, we need to make a copy because
#     817             #  series_generator will swap out the underlying data
#     818             results[i] = results[i].copy(deep=False)
#
# Cell In[11], line 5, in <lambda>(x)
#       1 expected_price = float(current_price.values[0]) - 10
#       3 print('expected price', expected_price)
# ----> 5 calls['gain'] = calls.apply(lambda x: -x['price'] if x['strike'] > expected_price else 100 * (expected_price-x['strike']-x['price'])/x['price'], axis = 1)
#       7 puts['gain'] = puts.apply(lambda x: -x['price'] if expected_price > x['strike']  else 100 * (x['strike'] - expected_price - x['price'])/x['price'], axis = 1)
#
# ZeroDivisionError: float division by zero

# %%
calls
# Out:
#     strike  lastPrice  bid  ask  volume  openInterest  impliedVolatility
# 0    150.0     130.35  0.0  0.0     2.0             0           0.000010  \
# 1    220.0      59.40  0.0  0.0     2.0             0           0.000010
# 2    230.0      82.65  0.0  0.0     NaN             0           0.000010
# 3    240.0      75.00  0.0  0.0     2.0             0           0.000010
# 4    245.0      76.87  0.0  0.0     1.0             0           0.000010
# ..     ...        ...  ...  ...     ...           ...                ...
# 57   415.0       0.15  0.0  0.0    39.0             0           0.125009
# 58   420.0       0.14  0.0  0.0    13.0             0           0.125009
# 59   435.0       0.07  0.0  0.0    60.0             0           0.125009
# 60   440.0       0.03  0.0  0.0     NaN             0           0.125009
# 61   445.0       0.05  0.0  0.0    22.0             0           0.125009
#
#       exp_date  bidSize  askSize  open  high  low  close  delta  gamma  vega
# 0   2023-06-02      NaN      NaN   NaN   NaN  NaN    NaN    1.0    NaN   NaN  \
# 1   2023-06-02      NaN      NaN   NaN   NaN  NaN    NaN    1.0    NaN   NaN
# 2   2023-06-02      NaN      NaN   NaN   NaN  NaN    NaN    1.0    NaN   NaN
# 3   2023-06-02      NaN      NaN   NaN   NaN  NaN    NaN    1.0    NaN   NaN
# 4   2023-06-02      NaN      NaN   NaN   NaN  NaN    NaN    1.0    NaN   NaN
# ..         ...      ...      ...   ...   ...  ...    ...    ...    ...   ...
# 57  2023-08-18      NaN      NaN   NaN   NaN  NaN    NaN    1.0    NaN   NaN
# 58  2023-08-18      NaN      NaN   NaN   NaN  NaN    NaN    1.0    NaN   NaN
# 59  2023-08-18      NaN      NaN   NaN   NaN  NaN    NaN    1.0    NaN   NaN
# 60  2023-08-18      NaN      NaN   NaN   NaN  NaN    NaN    1.0    NaN   NaN
# 61  2023-08-18      NaN      NaN   NaN   NaN  NaN    NaN    1.0    NaN   NaN
#
#     theta  sigma  price
# 0     NaN    NaN    0.0
# 1     NaN    NaN    0.0
# 2     NaN    NaN    0.0
# 3     NaN    NaN    0.0
# 4     NaN    NaN    0.0
# ..    ...    ...    ...
# 57    NaN    NaN    0.0
# 58    NaN    NaN    0.0
# 59    NaN    NaN    0.0
# 60    NaN    NaN    0.0
# 61    NaN    NaN    0.0
#
# [333 rows x 20 columns]

# %%
puts
