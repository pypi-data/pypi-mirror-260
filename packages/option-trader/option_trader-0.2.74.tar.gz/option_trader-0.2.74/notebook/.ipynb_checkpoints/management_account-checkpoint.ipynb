# %%
mlist =['AAPL','MSFT','NVDA','TSLA','ADBE','NFLX','QCOM','SHOP','ERF',
        'ABNB','ABT','AMAT','AMD','AMZN','ASML','AVGO','BA','BAC','BKNG',
        'CMG','COST','CRM','CUK','DOCU','DPZ','ETSY','F','FTNT','GOOGL',
        'ILMN','ISRG','KLAC','MCD','LRCX','MEDP','META','MRVL','MU','NKE',
        'ORCL','PANW','PFE','PLTR','PLUG','PYPL','QQQ','SPY','ROKU','RSG',
        'SBUX','SNOW','SQ','SWKS','TGT','TMO','TSM','TWLO','TXN','UPST',
        'VEEV','WMT', 'BLDR', 'TQQQ', 'V', 'JNJ', "NVDA", "AMD", "TSM", 
        "SMCI", "INTC", "SIMO","NXPI","AMBA","WDC","STX","ASX","EWBC","AAOI"]

#watchlist = ['MSFT', 'AAPL', 'AMZN', 'NVDA', 'BLDR', 'GOOGL', 'NFLX', 'META', 'SPY', 'QQQ', 'AMD', 'TSLA', 'ISRG']

watchlist = ['V', 'JNJ', 'MSFT', 'AAPL', 'AMZN', 'NVDA', 'BLDR', 'COST', 'GOOGL', 'NFLX', 'META', 'SPY', 'QQQ', 'AMD', 'ISRG', 'BRK-B']

SC_watchlist = ["NVDA", "AMD", "TSM", "AMAT", "MU", "LRCX", "ASML", "SMCI", "INTC", "SIMO","NXPI","AMBA","QCOM","WDC","STX","ASX","EWBC","AAOI",'4967.TW', '2363.TW']

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from xgboost import XGBClassifier
from sklearn import metrics
 
import warnings
warnings.filterwarnings('ignore')

# %%
import sys

sys.path.append(r'\Users\jimhu\option_trader\src')
  
from option_trader.admin.site import site
from option_trader.admin.user import user
from option_trader.consts import strategy as st

mysite = site('mysite')

# %%
jihuang = mysite.create_user('jihuang')
chrishua = mysite.create_user('chrishua')
stester = mysite.create_user('stester')
andyhua = mysite.create_user('andyhua')
dennishua = mysite.create_user('dennishua')
jay = mysite.create_user('jay')
lishuan = mysite.create_user('lishuan')
winwin = mysite.create_user('winwin')
jasonhsia = mysite.create_user('jasonhsia')
algo_11_07 = mysite.create_user('algo_11_07')

chrishua.update_user_email('chrishua123@hotmail.com')
stester.update_user_email('jim.huang.bellevue@gmail.com')
andyhua.update_user_email('jim.huang.bellevue@gmail.com')
dennishua.update_user_email('dennhua@live.com')
jihuang.update_user_email('jim.huang.bellevue@gmail.com')
lishuan.update_user_email('lishuanchen@berkeley.edu')
winwin.update_user_email('jim.huang.bellevue@gmail.com')
jasonhsia.update_user_email('bmanjasonh@gmail.com')
algo_11_07.update_user_email('jim.huang.bellevue@gmail.com')

chrishua.update_default_watchlist(mlist)
stester.update_default_watchlist(mlist)
algo_11_07.update_default_watchlist(mlist)
andyhua.update_default_watchlist(watchlist)
dennishua.update_default_watchlist(watchlist)
jihuang.update_default_watchlist(mlist)
lishuan.update_default_watchlist(watchlist)
winwin.update_default_watchlist(mlist)
jasonhsia.update_default_watchlist(SC_watchlist)
# Out:
# User jihuang already exists return existing user
# User chrishua already exists return existing user
# User stester already exists return existing user
# User andyhua already exists return existing user
# User dennishua already exists return existing user
# User jay already exists return existing user
# User lishuan already exists return existing user
# User winwin already exists return existing user
# User jasonhsia already exists return existing user
# User algo_11_07 already exists return existing user
# ['NVDA',
#  'AMD',
#  'TSM',
#  'AMAT',
#  'MU',
#  'LRCX',
#  'ASML',
#  'SMCI',
#  'INTC',
#  'SIMO',
#  'NXPI',
#  'AMBA',
#  'QCOM',
#  'WDC',
#  'STX',
#  'ASX',
#  'EWBC',
#  'AAOI',
#  '4967.TW',
#  '2363.TW']

# %%
jason_watchlist = ["NVDA", "AMD", "TSM", "AMAT", "MU", "LRCX", "ASML", "SMCI", "INTC", "SIMO","NXPI","AMBA","QCOM","WDC","STX","ASX","EWBC","AAOI"]
jason_strategy = [st.CREDIT_PUT_SPREAD, st.CREDIT_IRON_CONDOR, st.IRON_BUTTERFLY, st.CREDIT_PUT_BUTTERFLY]
jasonhsia_winwin = jasonhsia.create_account('winwin')
#jasonhsia_winwin.set_initial_balance(1000000)

jasonhsia_winwin.update_default_watchlist(jason_watchlist)
jasonhsia_winwin.update_default_strategy(jason_strategy)
# Out:
# Account winwin already exist return existing one

# %%
chrishua_winwin = chrishua.create_account('winwin')
#chrishua_winwin.set_initial_balance(1000000)
win_strategy = [st.WEEKLY_STOCK_TRADE, st.COVERED_CALL, st.SHORT_PUT, st.CREDIT_PUT_SPREAD, st.CREDIT_IRON_CONDOR, st.IRON_BUTTERFLY, st.CREDIT_PUT_BUTTERFLY]
chrishua_winwin.update_default_watchlist(mlist)
chrishua_winwin.update_default_strategy(win_strategy)
# Out:
# Account winwin already exist return existing one

# %%
jihuang_winwin = jihuang.create_account('winwin')
#jihuang_winwin.set_initial_balance(1000000)
win_strategy = [st.WEEKLY_STOCK_TRADE, st.COVERED_CALL, st.SHORT_PUT, st.CREDIT_PUT_SPREAD, st.CREDIT_IRON_CONDOR, st.IRON_BUTTERFLY, st.CREDIT_PUT_BUTTERFLY]
jihuang_winwin.update_default_watchlist(mlist)
jihuang_winwin.update_default_strategy(win_strategy)
# Out:
# Account winwin already exist return existing one

# %%
winwin_act = winwin.create_account('winwin')
#winwin_act.set_initial_balance(1000000)
win_strategy = [st.ALL_STRATEGY]
winwin_act.update_default_watchlist(mlist)
winwin_act.update_default_strategy(win_strategy)
# Out:
# Account winwin already exist return existing one

# %%
dennis_weekly_trade = dennishua.create_account('weekly_trade')
dennis_weekly_trade.update_default_watchlist(watchlist)
dennis_weekly_trade.update_default_strategy([st.WEEKLY_STOCK_TRADE])
#dennis_weekly_trade.set_initial_balance(10000)
ec = dennis_weekly_trade.get_default_risk_mgr()
ec.stop_loss_percent = 100
ec.stop_gain_percent = 200
dennis_weekly_trade.update_default_risk_mgr(ec)
# Out:
# Account weekly_trade already exist return existing one

# %%
lishua_weekly_trade = lishuan.create_account('weekly_trade')
lishua_weekly_trade.update_default_watchlist(watchlist)
lishua_weekly_trade.update_default_strategy([st.WEEKLY_STOCK_TRADE])
#lishua_weekly_trade.set_initial_balance(10000)
ec = lishua_weekly_trade.get_default_risk_mgr()
ec.stop_loss_percent = 100
ec.stop_gain_percent = 200
lishua_weekly_trade.update_default_risk_mgr(ec)
# Out:
# Account weekly_trade already exist return existing one

# %%
iron_condor = stester.create_account('iron_condor')
iron_condor.update_default_strategy(st.IRON_CONDOR_LIST)
iron_condor.update_default_watchlist(mlist)
spread = stester.create_account('spread')
spread.update_default_strategy(st.SPREAD_LIST)
spread.update_default_watchlist(mlist)
butterfly = stester.create_account('butterfly')
butterfly.update_default_strategy(st.BUTTERFLY_LIST)
butterfly.update_default_watchlist(mlist)
single = stester.create_account('single')
single.update_default_strategy(st.SINGLE_LIST )
single.update_default_watchlist(mlist)
# Out:
# Account iron_condor already exist return existing one
# Account spread already exist return existing one
# Account butterfly already exist return existing one
# Account single already exist return existing one

# %%
algo_11_07_iron_condor = algo_11_07.create_account('iron_condor')
algo_11_07_iron_condor.update_default_strategy(st.IRON_CONDOR_LIST)
algo_11_07_iron_condor.update_default_watchlist(mlist)
algo_11_07_spread = algo_11_07.create_account('spread')
algo_11_07_spread.update_default_strategy(st.SPREAD_LIST)
algo_11_07_spread.update_default_watchlist(mlist)
algo_11_07_butterfly = algo_11_07.create_account('butterfly')
algo_11_07_butterfly.update_default_strategy(st.BUTTERFLY_LIST)
algo_11_07_butterfly.update_default_watchlist(mlist)
algo_11_07_single = algo_11_07.create_account('single')
algo_11_07_single.update_default_strategy(st.SINGLE_LIST )
algo_11_07_single.update_default_watchlist(mlist)
# Out:
# Account iron_condor already exist return existing one
# Account spread already exist return existing one
# Account butterfly already exist return existing one
# Account single already exist return existing one

# %%
from option_trader.admin import position_summary
from option_trader.admin import position
from option_trader.admin import transaction
from option_trader.admin import quote
from option_trader.consts import asset

acct = algo_11_07_iron_condor
opt = acct.get_position_summary()
pos = acct.get_positions()
trx = acct.get_transactions()
print('summary %d \tposition %d \ttrx %d \tInit %.2f' % (opt.shape[0], pos.shape[0], trx.shape[0], acct.get_initial_balance()))

cash_position = round(acct.get_BuyingPower(),2)
margin_position = round(acct.get_margin_position(),2)

print('cash=%.2f \tmargin=%.2f'%(cash_position, margin_position))

open_pos = pos[pos[position.STATUS]==asset.OPENED] 

bto_df = open_pos[open_pos[position.OPEN_ACTION] == asset.BUY_TO_OPEN]
sto_df = open_pos[open_pos[position.OPEN_ACTION] == asset.SELL_TO_OPEN]
bto_total = bto_df[position.CURRENT_VALUE].sum()
sto_total = sto_df[position.CURRENT_VALUE].sum()
asset_value = bto_total - sto_total

print('asset value %.2f bto %.2f \tsto %.2f' % (asset_value, bto_df[position.CURRENT_VALUE].sum(),sto_df[position.CURRENT_VALUE].sum()))

account_value = round(cash_position + margin_position + asset_value,2)   

print('account value %.2f\tasset value %.2f bto %.2f \tsto %.2f' % (account_value, asset_value, bto_df[position.CURRENT_VALUE].sum(),sto_df[position.CURRENT_VALUE].sum()))
# Out:
# summary 197 	position 790 	trx 788 	Init 100000.00
# cash=-358284.00 	margin=243200.00
# asset value 214924.00 bto 1156055.50 	sto 941131.50
# account value 99840.00	asset value 214924.00 bto 1156055.50 	sto 941131.50

# %%
import pandas as pd

df_single = single.get_position_summary()
print(df_single.groupby('strategy')['symbol'].count())
df_spread = spread.get_position_summary()
print(df_spread.groupby('strategy')['symbol'].count())
df_iron_condor = iron_condor.get_position_summary()
print(df_iron_condor.groupby('strategy')['symbol'].count())
df_butterfly = butterfly.get_position_summary()
print(df_butterfly.groupby('strategy')['symbol'].count())
df = pd.concat([df_single, df_spread, df_iron_condor, df_butterfly])
# Out:
# strategy
# Long Call    56
# Long Put     26
# Name: symbol, dtype: int64
# strategy
# Credit Call Spread    296
# Credit Put Spread     249
# Debit Put Spread       86
# Name: symbol, dtype: int64
# strategy
# Credit Iron Condor    137
# Debit Iron Condor     117
# Name: symbol, dtype: int64
# strategy
# Credit Call Butterfly     129
# Credit Put Butterfly      144
# Debit Call Butterfly       16
# Debit Put Butterfly        15
# Iron Butterfly             98
# Reverse Iron Butterfly     58
# Name: symbol, dtype: int64

# %%
from datetime import datetime

today = datetime.now().date()      

df['days_to_expire'] = df.apply(lambda x: (pd.Timestamp(x['exp_date']).date()-today).days, axis = 1)  

df['amount'] = df.apply(lambda x: x['last_price'] * x['quantity'], axis = 1)  

df['amount'] = df.apply(lambda x: x['amount'] * 100 if x['strategy'] != 'Unpaird' else x['amount'], axis = 1)  

df['amount'] = df.apply(lambda x: -1 * x['amount'] if ['credit'] else x['amount'], axis = 1)  

df['amount']
# Out:
# 0     -1268.0
# 1     -1755.0
# 2      1121.0
# 3     -1303.0
# 4     -2780.0
#         ...
# 455   -1504.0
# 456   -1560.0
# 457   -1246.0
# 458   -1309.0
# 459   -2510.0
# Name: amount, Length: 1427, dtype: float64

# %%
#df_iron_condor[['symbol', 'strategy', 'open_price', 'quantity', 'spread', 'max_profit', 'max_loss', 'win_prob', 'exp_date', 'breakeven_l', 'breakeven_h', 'leg 1 otype', 'leg 1 strike', 'leg 1 open_action', 'leg 1 price', 'leg 2 otype',  'leg 2 strike', 'leg 2 open_action', 'leg 2 price',  'leg 3 otype', 'leg 3 strike', 'leg 3 open_action', 'leg 3 price', 'leg 4 otype',  'leg 4 strike', 'leg 4 open_action', 'leg 4 price']]

df.sort_values('exp_date', inplace=True)

dfc = df[df['status'] == 'closed']

dfo = df[df['status'] == 'opened']

#df[df['status'] == 'closed'][['symbol', 'strategy', 'open_price', 'quantity', 'spread', 'max_profit', 'max_loss', 'pnl', 'win_prob', 'gain', 'exp_date', 'status']] #, 'breakeven_l', 'breakeven_h', 'leg 1 otype', 'leg 1 strike', 'leg 1 open_action', 'leg 1 price', 'leg 2 otype',  'leg 2 strike', 'leg 2 open_action', 'leg 2 price',  'leg 3 otype', 'leg 3 strike', 'leg 3 open_action', 'leg 3 price', 'leg 4 otype',  'leg 4 strike', 'leg 4 open_action', 'leg 4 price']]

# %%
strategy_list = df['strategy'].unique()

for strategy in strategy_list:
    d4 = dfc[dfc['strategy'] == strategy] 
    print(d4.shape[0], '\t', d4['pl'].sum(), '\t', d4[d4['pl']>0].shape[0], ':', d4.shape[0], '\t', strategy)
# Out:
# 37 	 -15793.0 	 12 : 37 	 Long Call
# 10 	 5610.0 	 6 : 10 	 Debit Put Butterfly
# 56 	 256187.0 	 42 : 56 	 Credit Call Butterfly
# 58 	 36703.0 	 35 : 58 	 Credit Put Butterfly
# 34 	 43175.0 	 23 : 34 	 Reverse Iron Butterfly
# 117 	 87259.0 	 98 : 117 	 Credit Call Spread
# 10 	 -712.0 	 4 : 10 	 Debit Call Butterfly
# 67 	 101111.0 	 44 : 67 	 Debit Iron Condor
# 36 	 4760.0 	 25 : 36 	 Iron Butterfly
# 131 	 -90313.0 	 37 : 131 	 Credit Put Spread
# 20 	 42175.0 	 19 : 20 	 Long Put
# 50 	 253224.0 	 43 : 50 	 Debit Put Spread
# 64 	 -1254.0 	 33 : 64 	 Credit Iron Condor

# %%
strategy_list = df['strategy'].unique()

for strategy in strategy_list:
    d4 = dfo[dfo['strategy'] == strategy] 
    print(d4.shape[0], '\t', d4['pl'].sum(), '\t', d4[d4['pl']>0].shape[0], ':', d4.shape[0], '\t', strategy)
# Out:
# 13 	 -933.0 	 6 : 13 	 Long Call
# 2 	 0.0 	 0 : 2 	 Debit Put Butterfly
# 60 	 -3272.0 	 8 : 60 	 Credit Call Butterfly
# 68 	 -398.0 	 13 : 68 	 Credit Put Butterfly
# 14 	 -2453.0 	 3 : 14 	 Reverse Iron Butterfly
# 148 	 -16929.0 	 55 : 148 	 Credit Call Spread
# 3 	 0.0 	 0 : 3 	 Debit Call Butterfly
# 33 	 -9161.0 	 9 : 33 	 Debit Iron Condor
# 52 	 456.0 	 11 : 52 	 Iron Butterfly
# 92 	 37107.0 	 76 : 92 	 Credit Put Spread
# 4 	 -20.0 	 1 : 4 	 Long Put
# 24 	 372.0 	 9 : 24 	 Debit Put Spread
# 57 	 20652.0 	 45 : 57 	 Credit Iron Condor

# %%
exp_date_list = df['exp_date'].unique()

strategy_list = df['strategy'].unique()

for exp_date in exp_date_list:
    print(exp_date)
    for strategy in strategy_list:
        d4 = df[(df['exp_date'] == exp_date) & (df['strategy'] == strategy)] # & (df['status'] != 'opened') ]
        if d4.shape[0] > 0:
            print('\t',strategy, d4['symbol'].unique())            
            print('\t Win%% %.2f [%d|%d] \tPL %.2f' % (round(100*d4[d4['pl']>0].shape[0]/d4.shape[0],2), d4[d4['pl']>0].shape[0], d4.shape[0], d4['pl'].sum()))
# Out:
# 2023-09-15
# 	 Long Call ['AAPL' 'BLDR' 'SHOP' 'PLTR' 'KLAC' 'ISRG' 'TSLA' 'AMAT' 'MRVL']
# 	 Win% 55.56 [5|9] 	PL 31.00
# 	 Debit Put Butterfly ['QCOM' 'AAPL' 'PYPL' 'SWKS' 'MRVL']
# 	 Win% 60.00 [3|5] 	PL 4637.00
# 	 Credit Call Butterfly ['GOOGL' 'FTNT' 'DPZ' 'DOCU' 'AMZN' 'ADBE' 'TSM' 'TWLO' 'UPST' 'COST'
#  'PFE' 'SNOW' 'SBUX' 'ROKU' 'SQ']
# 	 Win% 80.00 [12|15] 	PL 67892.00
# 	 Credit Put Butterfly ['DPZ' 'COST' 'GOOGL' 'AMZN' 'TSM' 'TWLO' 'UPST' 'V' 'MCD' 'ROKU' 'SBUX'
#  'SQ']
# 	 Win% 50.00 [6|12] 	PL 4169.00
# 	 Reverse Iron Butterfly ['BLDR' 'SWKS' 'PYPL' 'ISRG' 'MRVL' 'KLAC' 'AVGO' 'QCOM' 'SHOP']
# 	 Win% 77.78 [7|9] 	PL 4311.00
# 	 Credit Call Spread ['SBUX' 'DOCU' 'COST' 'DPZ' 'FTNT' 'F' 'ERF' 'TWLO' 'V' 'UPST' 'CMG'
#  'META' 'ILMN' 'MCD' 'ROKU']
# 	 Win% 46.67 [7|15] 	PL -1473.00
# 	 Debit Call Butterfly ['AAPL' 'QCOM' 'SWKS']
# 	 Win% 0.00 [0|3] 	PL -1096.00
# 	 Debit Iron Condor ['VEEV' 'TSLA' 'AAPL' 'ISRG' 'QCOM' 'PYPL' 'PLTR' 'PANW' 'NVDA' 'MRVL'
#  'ABNB' 'BLDR' 'AVGO' 'KLAC' 'AMAT' 'SHOP' 'SWKS']
# 	 Win% 58.82 [10|17] 	PL 28343.00
# 	 Iron Butterfly ['TSM' 'TWLO' 'UPST' 'MCD' 'PFE' 'DOCU' 'SQ' 'SBUX']
# 	 Win% 100.00 [8|8] 	PL 3184.00
# 	 Credit Put Spread ['AMZN' 'CMG' 'COST' 'ADBE' 'MCD' 'DOCU' 'TSM' 'TWLO' 'FTNT' 'UPST' 'DPZ'
#  'MSFT' 'META' 'SBUX' 'GOOGL' 'PLUG' 'ROKU']
# 	 Win% 82.35 [14|17] 	PL 10845.00
# 	 Long Put ['AMAT' 'ISRG' 'BLDR' 'PYPL' 'SHOP']
# 	 Win% 80.00 [4|5] 	PL 6152.00
# 	 Debit Put Spread ['AMAT' 'AAPL' 'AVGO' 'ISRG' 'SHOP' 'TSLA' 'SWKS' 'PYPL' 'MRVL' 'QCOM'
#  'NVDA' 'PLTR']
# 	 Win% 75.00 [9|12] 	PL 35431.00
# 	 Credit Iron Condor ['MSFT' 'META' 'MCD' 'AMZN' 'CMG' 'DPZ' 'ILMN' 'ROKU' 'ADBE' 'COST' 'V']
# 	 Win% 63.64 [7|11] 	PL -819.00
# 2023-09-18
# 	 Credit Put Butterfly ['SPY']
# 	 Win% 0.00 [0|1] 	PL -1057.00
# 	 Credit Call Spread ['SPY']
# 	 Win% 100.00 [1|1] 	PL 1443.00
# 	 Credit Put Spread ['SPY']
# 	 Win% 0.00 [0|1] 	PL -2480.00
# 2023-09-19
# 	 Credit Put Butterfly ['SPY']
# 	 Win% 0.00 [0|1] 	PL -2177.00
# 	 Credit Call Spread ['SPY']
# 	 Win% 100.00 [1|1] 	PL 1258.00
# 	 Credit Put Spread ['SPY']
# 	 Win% 0.00 [0|1] 	PL -2394.00
# 	 Credit Iron Condor ['SPY']
# 	 Win% 100.00 [1|1] 	PL 513.00
# 2023-09-20
# 	 Credit Put Butterfly ['SPY']
# 	 Win% 0.00 [0|1] 	PL -795.00
# 	 Credit Call Spread ['SPY']
# 	 Win% 100.00 [1|1] 	PL 882.00
# 	 Credit Put Spread ['SPY']
# 	 Win% 0.00 [0|1] 	PL -804.00
# 	 Credit Iron Condor ['SPY']
# 	 Win% 100.00 [1|1] 	PL 36.00
# 2023-09-21
# 	 Credit Put Butterfly ['SPY']
# 	 Win% 100.00 [1|1] 	PL 1510.00
# 	 Credit Call Spread ['SPY']
# 	 Win% 100.00 [1|1] 	PL 1311.00
# 	 Credit Put Spread ['SPY']
# 	 Win% 0.00 [0|1] 	PL -2364.00
# 	 Credit Iron Condor ['SPY']
# 	 Win% 0.00 [0|1] 	PL -2489.00
# 2023-09-22
# 	 Long Call ['AAPL' 'AMAT' 'PANW' 'KLAC' 'SHOP' 'PLTR' 'MRVL' 'ISRG' 'ORCL']
# 	 Win% 0.00 [0|9] 	PL -11391.00
# 	 Debit Put Butterfly ['ORCL' 'AAPL' 'PYPL' 'SWKS']
# 	 Win% 50.00 [2|4] 	PL 643.00
# 	 Credit Call Butterfly ['UPST' 'TWLO' 'TSM' 'SBUX' 'ROKU' 'SQ' 'PFE' 'MCD' 'FTNT' 'DOCU' 'COST'
#  'AMZN' 'ILMN' 'DPZ']
# 	 Win% 86.67 [13|15] 	PL 101876.00
# 	 Credit Put Butterfly ['V' 'ROKU' 'MU' 'ETSY' 'TXN' 'UPST' 'TWLO' 'TSM' 'SPY' 'SBUX' 'FTNT' 'SQ'
#  'MCD' 'GOOGL' 'DPZ' 'DOCU' 'ILMN' 'AMZN' 'COST']
# 	 Win% 65.00 [13|20] 	PL 7459.00
# 	 Reverse Iron Butterfly ['SWKS' 'ORCL' 'QCOM' 'ISRG' 'SHOP' 'MRVL' 'PYPL' 'ABNB' 'AAPL' 'AVGO']
# 	 Win% 70.00 [7|10] 	PL 4914.00
# 	 Credit Call Spread ['COST' 'SBUX' 'ILMN' 'DOCU' 'DPZ' 'F' 'FTNT' 'BAC' 'PLUG' 'ROKU' 'V'
#  'UPST' 'TWLO' 'META' 'MCD' 'PFE' 'PYPL' 'SNOW' 'TSM' 'SPY' 'TXN' 'ETSY'
#  'MU']
# 	 Win% 92.59 [25|27] 	PL 29545.00
# 	 Debit Call Butterfly ['ORCL' 'PYPL' 'AAPL']
# 	 Win% 66.67 [2|3] 	PL 710.00
# 	 Debit Iron Condor ['ORCL' 'QCOM' 'AMAT' 'AAPL' 'SWKS' 'NFLX' 'TSLA' 'MRVL' 'SHOP' 'ABNB'
#  'ISRG' 'PANW' 'AVGO' 'NVDA' 'PYPL' 'PLTR' 'KLAC']
# 	 Win% 66.67 [14|21] 	PL 18828.00
# 	 Iron Butterfly ['ROKU' 'PYPL' 'V' 'TSM' 'TXN' 'SQ' 'UPST' 'TWLO' 'SBUX' 'MCD' 'PFE'
#  'DOCU']
# 	 Win% 50.00 [6|12] 	PL -650.00
# 	 Credit Put Spread ['COST' 'GOOGL' 'SBUX' 'BAC' 'MSFT' 'DPZ' 'ROKU' 'PFE' 'AMZN' 'META' 'V'
#  'UPST' 'TSM' 'TWLO' 'ADBE' 'CMG' 'MCD' 'DOCU' 'BA' 'MU' 'SNOW' 'SPY']
# 	 Win% 12.50 [3|24] 	PL -32380.00
# 	 Long Put ['AMAT' 'SWKS' 'PYPL' 'QCOM' 'SHOP']
# 	 Win% 100.00 [7|7] 	PL 15251.00
# 	 Debit Put Spread ['SHOP' 'ORCL' 'SWKS' 'AMAT' 'PLTR' 'AVGO' 'QCOM' 'ISRG' 'PYPL' 'MRVL'
#  'AAPL' 'KLAC' 'TSLA' 'ABNB' 'NVDA' 'NFLX']
# 	 Win% 89.47 [17|19] 	PL 120348.00
# 	 Credit Iron Condor ['ADBE' 'TWLO' 'TSM' 'SPY' 'ROKU' 'MSFT' 'MCD' 'GOOGL' 'CMG' 'COST' 'AMZN'
#  'DPZ' 'META' 'V']
# 	 Win% 35.71 [5|14] 	PL -3308.00
# 2023-09-29
# 	 Long Call ['ORCL' 'ISRG' 'PANW' 'ABNB' 'AMZN' 'PLTR' 'AAPL' 'MRVL' 'SHOP']
# 	 Win% 20.00 [2|10] 	PL -22523.00
# 	 Debit Put Butterfly ['AMZN' 'PYPL' 'AAPL']
# 	 Win% 0.00 [0|3] 	PL -21450.00
# 	 Credit Call Butterfly ['TSM' 'ADBE' 'AMZN' 'COST' 'ROKU' 'SQ' 'GOOGL' 'PYPL' 'SNOW' 'UPST'
#  'DOCU' 'SBUX' 'V' 'FTNT' 'TWLO' 'ILMN']
# 	 Win% 62.50 [10|16] 	PL 188131.00
# 	 Credit Put Butterfly ['AMZN' 'ROKU' 'SBUX' 'TSM' 'GOOGL' 'JNJ' 'WMT' 'PYPL' 'TGT' 'SQ' 'DOCU'
#  'SPY' 'V' 'UPST' 'DPZ' 'FTNT' 'MCD' 'TWLO' 'MU']
# 	 Win% 14.29 [3|21] 	PL -31753.00
# 	 Reverse Iron Butterfly ['AAPL' 'ABNB' 'SHOP' 'SWKS' 'AMZN' 'PYPL' 'MRVL' 'PLTR' 'QCOM' 'ORCL']
# 	 Win% 9.09 [1|11] 	PL -44560.00
# 	 Credit Call Spread ['ETSY' 'SQ' 'V' 'SPY' 'ILMN' 'ROKU' 'SBUX' 'DOCU' 'FTNT' 'PFE' 'SNOW' 'F'
#  'UPST' 'MCD' 'PLUG' 'META' 'PYPL' 'TWLO' 'JNJ' 'COST' 'DPZ' 'BA' 'MU'
#  'GOOGL']
# 	 Win% 92.86 [26|28] 	PL 49751.00
# 	 Debit Call Butterfly ['AAPL' 'AMZN' 'ORCL']
# 	 Win% 0.00 [0|3] 	PL -7705.00
# 	 Debit Iron Condor ['PANW' 'AAPL' 'SHOP' 'QCOM' 'ABNB' 'ISRG' 'NVDA' 'AVGO' 'MRVL' 'SWKS'
#  'PLTR' 'TSLA' 'PYPL' 'AMAT' 'NFLX' 'ORCL' 'AMZN' 'KLAC']
# 	 Win% 21.74 [5|23] 	PL -57186.00
# 	 Iron Butterfly ['TSM' 'PYPL' 'TXN' 'WMT' 'DOCU' 'SQ' 'SBUX' 'PFE' 'BAC' 'GOOGL' 'JNJ']
# 	 Win% 45.45 [5|11] 	PL 3426.00
# 	 Credit Put Spread ['SBUX' 'BAC' 'V' 'SNOW' 'BA' 'UPST' 'GOOGL' 'MU' 'META' 'SPY' 'ROKU'
#  'COST' 'TSM' 'PYPL' 'FTNT' 'CMG' 'MCD' 'AMZN' 'JNJ' 'TWLO' 'ADBE' 'F'
#  'DPZ' 'NVDA' 'WMT']
# 	 Win% 20.59 [7|34] 	PL -37305.00
# 	 Long Put ['AMAT' 'ABNB' 'SHOP' 'PYPL' 'SWKS' 'ISRG']
# 	 Win% 66.67 [4|6] 	PL 2080.00
# 	 Debit Put Spread ['AVGO' 'AMZN' 'SWKS' 'SHOP' 'QCOM' 'PYPL' 'ORCL' 'MRVL' 'ISRG' 'TSLA'
#  'AMAT' 'AAPL' 'ABNB']
# 	 Win% 29.41 [5|17] 	PL -6885.00
# 	 Credit Iron Condor ['MU' 'BA' 'AMZN' 'ILMN' 'CMG' 'DPZ' 'META' 'TSM' 'COST' 'ROKU' 'TWLO'
#  'GOOGL' 'ADBE' 'V' 'SPY' 'MCD']
# 	 Win% 37.50 [6|16] 	PL -16217.00
# 2023-10-02
# 	 Credit Call Butterfly ['QQQ']
# 	 Win% 0.00 [0|1] 	PL -108.00
# 	 Credit Call Spread ['QQQ']
# 	 Win% 100.00 [1|1] 	PL 1206.00
# 	 Credit Put Spread ['QQQ']
# 	 Win% 100.00 [1|1] 	PL 1330.00
# 	 Credit Iron Condor ['QQQ']
# 	 Win% 100.00 [1|1] 	PL 1278.00
# 2023-10-03
# 	 Credit Call Butterfly ['QQQ']
# 	 Win% 0.00 [0|1] 	PL -152.00
# 	 Credit Call Spread ['QQQ']
# 	 Win% 100.00 [1|1] 	PL 486.00
# 	 Credit Put Spread ['QQQ']
# 	 Win% 100.00 [1|1] 	PL 190.00
# 	 Credit Iron Condor ['QQQ']
# 	 Win% 100.00 [1|1] 	PL 732.00
# 2023-10-04
# 	 Credit Call Spread ['QQQ']
# 	 Win% 100.00 [1|1] 	PL 1251.00
# 	 Credit Put Spread ['QQQ']
# 	 Win% 100.00 [1|1] 	PL 1224.00
# 	 Credit Iron Condor ['QQQ']
# 	 Win% 100.00 [1|1] 	PL 1248.00
# 2023-10-05
# 	 Credit Call Butterfly ['QQQ']
# 	 Win% 0.00 [0|1] 	PL -404.00
# 	 Credit Call Spread ['QQQ' 'SPY']
# 	 Win% 100.00 [3|3] 	PL 4216.00
# 	 Credit Put Spread ['QQQ' 'SPY']
# 	 Win% 33.33 [1|3] 	PL 1294.00
# 	 Credit Iron Condor ['SPY' 'QQQ']
# 	 Win% 100.00 [2|2] 	PL 1983.00
# 2023-10-06
# 	 Long Call ['ISRG' 'AAPL' 'AVGO' 'ABNB' 'PLTR' 'AMZN' 'SHOP' 'ORCL' 'MRVL']
# 	 Win% 30.77 [4|13] 	PL -4549.00
# 	 Debit Put Butterfly ['AAPL']
# 	 Win% 100.00 [1|1] 	PL 330.00
# 	 Credit Call Butterfly ['JNJ' 'NKE' 'SBUX' 'MU' 'QQQ' 'AMD' 'TXN' 'ROKU' 'GOOGL' 'UPST' 'V' 'DPZ'
#  'TSM' 'SNOW' 'SQ' 'FTNT' 'DOCU' 'PFE']
# 	 Win% 68.42 [13|19] 	PL 36629.00
# 	 Credit Put Butterfly ['MRVL' 'NKE' 'MU' 'AMD' 'QQQ' 'PYPL' 'SBUX' 'TWLO' 'V' 'GOOGL' 'UPST'
#  'AMZN' 'TSM' 'BAC' 'SQ' 'DOCU' 'COST' 'ADBE']
# 	 Win% 61.11 [11|18] 	PL 6753.00
# 	 Reverse Iron Butterfly ['QCOM' 'V' 'PLTR' 'ABNB' 'ORCL' 'AMZN' 'AAPL' 'PYPL' 'SWKS' 'SHOP' 'MRVL'
#  'PANW']
# 	 Win% 57.14 [8|14] 	PL 28360.00
# 	 Credit Call Spread ['SHOP' 'SNOW' 'SPY' 'MSFT' 'MU' 'PANW' 'PLTR' 'LRCX' 'NVDA' 'ROKU' 'TWLO'
#  'TXN' 'WMT' 'AMAT' 'QQQ' 'PYPL' 'AVGO' 'META' 'PFE' 'FTNT' 'ETSY' 'DOCU'
#  'TQQQ' 'PLUG' 'TSM' 'F' 'ILMN' 'V' 'MCD' 'SQ' 'SBUX' 'MRVL' 'CRM' 'UPST'
#  'BA' 'NFLX' 'ABT' 'AMD' 'BAC' 'GOOGL' 'JNJ']
# 	 Win% 89.39 [59|66] 	PL 52773.00
# 	 Debit Call Butterfly ['SHOP' 'AAPL' 'AMZN' 'ORCL']
# 	 Win% 50.00 [2|4] 	PL -326.00
# 	 Debit Iron Condor ['ABNB' 'AAPL' 'ORCL' 'AMZN' 'NFLX' 'KLAC' 'ISRG' 'PLTR' 'MRVL' 'NVDA'
#  'PYPL' 'AMAT' 'AVGO' 'PANW' 'TSLA' 'SHOP' 'QCOM' 'SWKS' 'MCD' 'V']
# 	 Win% 63.64 [14|22] 	PL 35425.00
# 	 Iron Butterfly ['MRVL' 'JNJ' 'GOOGL' 'MU' 'TSM' 'AMD' 'SQ' 'NKE' 'BAC' 'UPST' 'WMT'
#  'TQQQ' 'SBUX' 'PFE' 'DOCU']
# 	 Win% 73.33 [11|15] 	PL 3758.00
# 	 Credit Put Spread ['SPY' 'MU' 'PFE' 'JNJ' 'NFLX' 'QQQ' 'CMG' 'SNOW' 'FTNT' 'ROKU' 'TXN'
#  'TWLO' 'MCD' 'GOOGL' 'WMT' 'AMZN' 'TQQQ' 'DPZ' 'COST' 'META' 'TSM' 'MRVL'
#  'ADBE' 'CRM' 'BA' 'F' 'LRCX' 'ASML' 'UPST' 'BAC' 'SBUX' 'AMD' 'NVDA']
# 	 Win% 35.19 [19|54] 	PL -13728.00
# 	 Long Put ['QCOM' 'AMAT' 'SWKS']
# 	 Win% 100.00 [4|4] 	PL 9170.00
# 	 Debit Put Spread ['TSLA' 'NFLX' 'QCOM' 'PYPL' 'MRVL' 'SWKS' 'ABNB' 'ISRG' 'AMZN' 'AAPL'
#  'ORCL' 'PLTR' 'SHOP']
# 	 Win% 85.71 [12|14] 	PL 32956.00
# 	 Credit Iron Condor ['SPY' 'AMZN' 'V' 'GOOGL' 'MCD' 'CMG' 'DPZ' 'COST' 'META' 'SBUX' 'ADBE'
#  'QQQ' 'DOCU' 'ASML' 'TWLO' 'TSM' 'WMT' 'MU' 'ROKU' 'NVDA' 'AMD' 'TXN'
#  'NKE' 'CRM' 'NFLX' 'TQQQ']
# 	 Win% 53.33 [16|30] 	PL 10414.00
# 2023-10-09
# 	 Credit Call Butterfly ['QQQ']
# 	 Win% 0.00 [0|1] 	PL -980.00
# 	 Credit Call Spread ['SPY' 'QQQ']
# 	 Win% 0.00 [0|3] 	PL -1462.00
# 	 Iron Butterfly ['SPY']
# 	 Win% 0.00 [0|1] 	PL 0.00
# 	 Credit Put Spread ['SPY' 'QQQ']
# 	 Win% 100.00 [3|3] 	PL 2910.00
# 	 Credit Iron Condor ['SPY' 'QQQ']
# 	 Win% 100.00 [2|2] 	PL 2299.00
# 2023-10-10
# 	 Credit Call Butterfly ['SPY' 'QQQ']
# 	 Win% 0.00 [0|2] 	PL -615.00
# 	 Credit Call Spread ['SPY' 'QQQ']
# 	 Win% 0.00 [0|4] 	PL -1844.00
# 	 Iron Butterfly ['SPY']
# 	 Win% 0.00 [0|1] 	PL 0.00
# 	 Credit Put Spread ['SPY' 'QQQ']
# 	 Win% 100.00 [4|4] 	PL 3956.00
# 	 Credit Iron Condor ['QQQ' 'SPY']
# 	 Win% 100.00 [2|2] 	PL 1661.00
# 2023-10-11
# 	 Credit Call Butterfly ['QQQ']
# 	 Win% 0.00 [0|1] 	PL -366.00
# 	 Credit Call Spread ['SPY' 'QQQ']
# 	 Win% 0.00 [0|4] 	PL -1520.00
# 	 Iron Butterfly ['SPY']
# 	 Win% 0.00 [0|1] 	PL 0.00
# 	 Credit Put Spread ['SPY' 'QQQ']
# 	 Win% 100.00 [4|4] 	PL 3204.00
# 	 Credit Iron Condor ['QQQ' 'SPY']
# 	 Win% 100.00 [2|2] 	PL 1564.00
# 2023-10-12
# 	 Credit Call Spread ['QQQ' 'SPY']
# 	 Win% 0.00 [0|4] 	PL -1382.00
# 	 Credit Put Spread ['QQQ' 'SPY']
# 	 Win% 100.00 [4|4] 	PL 2514.00
# 	 Credit Iron Condor ['QQQ' 'SPY']
# 	 Win% 100.00 [2|2] 	PL 1268.00
# 2023-10-13
# 	 Long Call ['PLTR' 'AMZN' 'SHOP' 'ORCL' 'MRVL' 'AAPL']
# 	 Win% 50.00 [3|6] 	PL -1024.00
# 	 Debit Put Butterfly ['ORCL' 'AMZN']
# 	 Win% 0.00 [0|2] 	PL 0.00
# 	 Credit Call Butterfly ['MRVL' 'UPST' 'TXN' 'WMT' 'NKE' 'SQ' 'TWLO' 'ROKU' 'MU' 'ETSY' 'CRM'
#  'GOOGL' 'QCOM' 'DOCU' 'PYPL' 'ABT' 'TSM' 'AMAT']
# 	 Win% 16.67 [3|18] 	PL 1007.00
# 	 Credit Put Butterfly ['QCOM' 'GOOGL' 'TWLO' 'TXN' 'JNJ' 'TSM' 'TMO' 'MRVL' 'SWKS' 'ROKU' 'SQ'
#  'UPST' 'AMD' 'PYPL' 'CRM' 'ETSY' 'AMAT' 'ABT' 'QQQ' 'WMT' 'MU' 'NKE']
# 	 Win% 22.73 [5|22] 	PL 744.00
# 	 Reverse Iron Butterfly ['ABNB' 'QCOM' 'AMZN' 'SHOP' 'AAPL']
# 	 Win% 60.00 [3|5] 	PL 220.00
# 	 Credit Call Spread ['AMD' 'V' 'WMT' 'SPY' 'TXN' 'SHOP' 'CRM' 'ETSY' 'MSFT' 'ABT' 'GOOGL'
#  'TQQQ' 'AMAT' 'UPST' 'PYPL' 'SBUX' 'ROKU' 'QQQ' 'SNOW' 'JNJ' 'TSM' 'MRVL'
#  'NFLX' 'BA' 'BAC' 'F' 'MU' 'PFE' 'SQ' 'PLUG']
# 	 Win% 53.49 [23|43] 	PL 3709.00
# 	 Debit Call Butterfly ['ORCL' 'AMZN']
# 	 Win% 0.00 [0|2] 	PL 0.00
# 	 Debit Iron Condor ['TSLA' 'AMZN' 'AAPL' 'ORCL' 'PLTR' 'QCOM' 'NFLX' 'V' 'SHOP' 'ABNB']
# 	 Win% 45.45 [5|11] 	PL -1566.00
# 	 Iron Butterfly ['UPST' 'WMT' 'TXN' 'JNJ' 'BAC' 'TWLO' 'SWKS' 'SQ' 'SBUX' 'ROKU' 'PYPL'
#  'AMAT' 'QCOM' 'ETSY' 'PFE' 'MRVL' 'TQQQ' 'MU' 'NKE' 'ABT' 'TSM']
# 	 Win% 19.05 [4|21] 	PL 1398.00
# 	 Credit Put Spread ['TSM' 'ABT' 'SPY' 'WMT' 'TQQQ' 'MRVL' 'SNOW' 'BAC' 'NFLX' 'BA' 'MU'
#  'UPST' 'JNJ' 'ROKU' 'V' 'QQQ' 'AMD' 'CRM' 'NVDA' 'F' 'GOOGL' 'META']
# 	 Win% 55.00 [22|40] 	PL -10947.00
# 	 Long Put ['ABNB' 'QCOM']
# 	 Win% 50.00 [1|2] 	PL 240.00
# 	 Debit Put Spread ['TSLA' 'ABNB' 'SHOP' 'AMZN' 'AAPL' 'QCOM' 'NFLX' 'ORCL']
# 	 Win% 62.50 [5|8] 	PL 3313.00
# 	 Credit Iron Condor ['SPY' 'GOOGL' 'META' 'WMT' 'NVDA' 'MU' 'TQQQ' 'QQQ' 'NFLX' 'AMD' 'CRM'
#  'COST' 'NKE']
# 	 Win% 71.43 [10|14] 	PL 5554.00
# 2023-10-20
# 	 Long Call ['AMZN' 'ABNB' 'ORCL' 'MRVL' 'PLTR' 'SHOP' 'BLDR']
# 	 Win% 28.57 [2|7] 	PL -345.00
# 	 Credit Call Butterfly ['ILMN' 'ETSY' 'TXN' 'PFE' 'UPST' 'MU' 'SBUX' 'JNJ' 'PYPL' 'GOOGL' 'SWKS'
#  'TGT' 'TSM' 'SQ' 'WMT' 'ROKU' 'MRVL' 'TWLO' 'RSG' 'QCOM' 'AMD' 'CMG'
#  'AMAT' 'CRM' 'FTNT' 'NKE']
# 	 Win% 19.23 [5|26] 	PL -1523.00
# 	 Credit Put Butterfly ['GOOGL' 'ILMN' 'AMD' 'PFE' 'SBUX' 'PYPL' 'JNJ' 'UPST' 'TGT' 'TSM' 'SQ'
#  'TXN' 'SWKS' 'WMT' 'MU' 'DOCU' 'ETSY' 'MRVL' 'CRM' 'TWLO' 'RSG' 'QCOM'
#  'ROKU' 'NKE']
# 	 Win% 25.00 [6|24] 	PL -716.00
# 	 Reverse Iron Butterfly ['AMZN' 'AAPL' 'SWKS' 'QCOM' 'MRVL' 'SHOP' 'V']
# 	 Win% 0.00 [0|7] 	PL -2346.00
# 	 Credit Call Spread ['ASML' 'ABT' 'BA' 'AMD' 'JNJ' 'SBUX' 'TXN' 'TSM' 'UPST' 'SNOW' 'V' 'VEEV'
#  'MRVL' 'WMT' 'CRM' 'LRCX' 'TQQQ' 'F' 'MU' 'DOCU' 'DPZ' 'BAC' 'NFLX' 'PFE'
#  'QQQ' 'SPY' 'ETSY' 'SHOP' 'ROKU' 'PYPL' 'MSFT' 'FTNT' 'PANW' 'AVGO'
#  'ISRG' 'AMAT' 'TMO' 'GOOGL' 'TWLO']
# 	 Win% 43.64 [24|55] 	PL -5386.00
# 	 Debit Iron Condor ['KLAC' 'MRVL' 'AVGO' 'AMZN' 'MCD' 'ABNB' 'AAPL' 'VEEV' 'TSLA' 'SWKS'
#  'QCOM' 'SHOP' 'ORCL' 'V' 'BLDR']
# 	 Win% 20.00 [3|15] 	PL -4890.00
# 	 Iron Butterfly ['ETSY' 'PFE' 'BAC' 'RSG' 'SBUX' 'SWKS' 'ABT' 'MRVL' 'TWLO' 'TQQQ' 'WMT'
#  'PYPL' 'MU' 'NKE']
# 	 Win% 50.00 [7|14] 	PL -16.00
# 	 Credit Put Spread ['TWLO' 'GOOGL' 'JNJ' 'AMD' 'BA' 'COST' 'WMT' 'SNOW' 'TQQQ' 'MRVL' 'CRM'
#  'ROKU' 'META' 'LRCX' 'MU' 'F' 'NVDA' 'BAC' 'ABT' 'NFLX' 'SPY' 'UPST'
#  'QQQ' 'TSM' 'DPZ']
# 	 Win% 63.33 [19|30] 	PL 689.00
# 	 Long Put ['QCOM']
# 	 Win% 0.00 [0|1] 	PL -60.00
# 	 Debit Put Spread ['AMZN' 'KLAC' 'AAPL' 'SWKS' 'ABNB' 'SHOP' 'QCOM' 'ORCL' 'TSLA']
# 	 Win% 22.22 [2|9] 	PL -1675.00
# 	 Credit Iron Condor ['MU' 'NVDA' 'QQQ' 'NFLX' 'META' 'WMT' 'AMD' 'DOCU' 'COST' 'JNJ' 'GOOGL'
#  'TQQQ' 'NKE' 'SPY' 'CRM' 'LRCX' 'ABT' 'TSM' 'BAC' 'PFE' 'SBUX']
# 	 Win% 76.19 [16|21] 	PL 4255.00
# 2023-10-27
# 	 Long Call ['AMZN' 'AAPL']
# 	 Win% 100.00 [2|2] 	PL 771.00
# 	 Credit Call Butterfly ['MU' 'ASML' 'ROKU' 'UPST' 'PYPL' 'MRVL' 'SBUX' 'SQ' 'QCOM']
# 	 Win% 11.11 [1|9] 	PL 234.00
# 	 Credit Put Butterfly ['AMD' 'PYPL' 'NKE' 'MRVL' 'UPST' 'ILMN' 'MU' 'JNJ' 'WMT' 'PFE' 'QCOM'
#  'SBUX' 'ETSY' 'ROKU' 'SQ' 'TWLO']
# 	 Win% 18.75 [3|16] 	PL 627.00
# 	 Reverse Iron Butterfly ['AAPL' 'SHOP']
# 	 Win% 0.00 [0|2] 	PL -327.00
# 	 Credit Call Spread ['SPY' 'CRM' 'SBUX' 'ETSY' 'SHOP' 'PANW' 'V' 'SQ' 'F' 'PYPL' 'TQQQ' 'MRVL'
#  'GOOGL' 'AMD' 'MSFT' 'MU' 'UPST' 'ROKU' 'NFLX' 'SNOW' 'BAC' 'TSM' 'QQQ']
# 	 Win% 24.32 [9|37] 	PL -8936.00
# 	 Debit Iron Condor ['AMZN' 'AAPL' 'ABNB' 'V' 'MCD' 'ORCL' 'SHOP' 'TSLA']
# 	 Win% 25.00 [2|8] 	PL -335.00
# 	 Iron Butterfly ['WMT' 'BAC' 'TQQQ' 'ABT' 'MRVL' 'SBUX' 'PFE' 'TWLO' 'PYPL']
# 	 Win% 0.00 [0|9] 	PL -926.00
# 	 Credit Put Spread ['META' 'TQQQ' 'ROKU' 'F' 'GOOGL' 'AMD' 'CRM' 'MU' 'SPY' 'JNJ' 'COST'
#  'UPST' 'QQQ' 'NFLX' 'SNOW' 'WMT' 'MRVL' 'BAC' 'NVDA' 'TSM']
# 	 Win% 80.00 [20|25] 	PL 4095.00
# 	 Long Put ['QCOM']
# 	 Win% 0.00 [0|1] 	PL -200.00
# 	 Debit Put Spread ['AAPL' 'ABNB' 'AMZN' 'SHOP' 'TSLA' 'ORCL' 'QCOM']
# 	 Win% 28.57 [2|7] 	PL -1266.00
# 	 Credit Iron Condor ['CRM' 'AMD' 'NFLX' 'META' 'GOOGL' 'MU' 'QQQ' 'TQQQ' 'WMT' 'SPY' 'NVDA'
#  'TSM' 'NKE' 'COST' 'PFE']
# 	 Win% 73.33 [11|15] 	PL 2759.00
# 2023-11-03
# 	 Credit Call Butterfly ['MU' 'MRVL' 'TSM' 'TWLO']
# 	 Win% 0.00 [0|4] 	PL 0.00
# 	 Credit Put Butterfly ['PYPL' 'SQ' 'TSM' 'TWLO' 'WMT' 'TQQQ' 'MU']
# 	 Win% 0.00 [0|7] 	PL 0.00
# 	 Debit Call Butterfly ['SHOP']
# 	 Win% 0.00 [0|1] 	PL 0.00
# 	 Iron Butterfly ['PFE' 'SBUX' 'BAC' 'ABT' 'WMT']
# 	 Win% 0.00 [0|5] 	PL 0.00

# %%
dff = df[df['pnl'] < 5]

dff = df[df['status'] != 'opened']

# %%
#d4 = df[df['strategy'] == st.CREDIT_PUT_SPREAD]
    
features = ['pnl', 'max_profit', 'max_loss', 'win_prob', 'gain', 'quantity', 'spread', 'days_to_expire']
 
plt.subplots(figsize=(20,10))
 
for i, col in enumerate(features):
    plt.subplot(3,3,i+1)
    sb.distplot(dff[col])

plt.show()

# %%
df[df['strategy'] == st.CREDIT_IRON_CONDOR].groupby('symbol')['symbol'].count()
# Out:
# symbol
# ADBE     4
# AMZN     4
# CMG      4
# COST     4
# DPZ      4
# GOOGL    1
# ILMN     2
# MCD      4
# META     4
# MSFT     2
# ROKU     4
# TSM      3
# TWLO     3
# V        3
# Name: symbol, dtype: int64

# %%
df[df['symbol']=='SPY'].groupby(['strategy','trade_date', 'exp_date','status', 'gain', 'pnl','win_prob', 'pl', 'status']).size()
# Out:
# strategy               trade_date                        exp_date    status  gain     pnl       win_prob  pl       status
# Credit Call Butterfly  2023-08-21 09:45:45.942804-04:00  2023-09-15  closed   92.68   0.694915  95.2       1596.0  closed    1
# Credit Call Spread     2023-08-19 22:08:55.126484-04:00  2023-09-08  opened  -7.25    0.526718  67.1      -95.0    opened    1
#                        2023-08-19 22:08:56.147589-04:00  2023-09-01  opened  -3.65    0.520913  67.7      -47.5    opened    1
#                        2023-08-19 22:08:57.040538-04:00  2023-08-25  expred   100.00  0.515152  70.7       1258.0  expred    1
#                        2023-08-19 22:08:57.653086-04:00  2023-09-15  opened  -1.49    0.503759  63.1      -18.5    opened    1
#                        2023-08-19 23:03:27.343739-04:00  2023-09-01  opened  -3.65    0.520913  65.9      -47.5    opened    1
#                        2023-08-19 23:03:28.673380-04:00  2023-08-25  expred   100.00  0.515152  68.6       1258.0  expred    1
#                        2023-08-19 23:03:29.689715-04:00  2023-09-08  opened  -7.25    0.526718  65.2      -95.0    opened    1
#                        2023-08-19 23:03:31.298713-04:00  2023-09-15  opened  -1.49    0.503759  63.7      -18.5    opened    1
# Credit Iron Condor     2023-08-19 21:43:35.296333-04:00  2023-09-01  opened   61.76   0.515152  72.5       756.0   opened    1
#                        2023-08-19 21:43:51.351297-04:00  2023-09-08  opened   36.00   0.500000  70.2       432.0   opened    1
#                        2023-08-19 21:44:42.293003-04:00  2023-09-15  opened   29.00   0.500000  70.0       348.0   opened    1
#                        2023-08-19 22:10:42.909542-04:00  2023-09-01  opened   53.00   0.500000  72.7       636.0   opened    1
#                        2023-08-19 22:10:56.365955-04:00  2023-09-08  opened   36.00   0.500000  70.4       432.0   opened    1
#                        2023-08-19 22:11:17.681912-04:00  2023-09-15  opened   24.75   0.507538  69.8       300.0   opened    1
#                        2023-08-19 23:05:25.297588-04:00  2023-09-01  opened   61.19   0.503759  74.1       738.0   opened    1
#                        2023-08-19 23:05:34.445190-04:00  2023-09-08  opened   36.00   0.500000  68.5       432.0   opened    1
#                        2023-08-19 23:05:56.368542-04:00  2023-09-15  opened   24.75   0.507538  70.3       300.0   opened    1
# Credit Put Spread      2023-08-19 22:07:44.830644-04:00  2023-09-08  opened   35.29   0.515152  66.5       432.0   opened    1
#                        2023-08-19 22:07:46.210123-04:00  2023-09-01  opened   50.00   0.515152  70.1       629.0   opened    1
#                        2023-08-19 22:07:47.492300-04:00  2023-08-25  expred   100.00  0.503759  70.5       1206.0  expred    1
#                        2023-08-19 22:07:48.432026-04:00  2023-09-15  opened   26.87   0.503759  74.0       324.0   opened    1
#                        2023-08-19 23:02:13.858613-04:00  2023-09-01  opened   50.00   0.515152  72.2       629.0   opened    1
#                        2023-08-19 23:02:14.679648-04:00  2023-08-25  expred   100.00  0.503759  72.1       1206.0  expred    1
#                        2023-08-19 23:02:15.411941-04:00  2023-09-08  opened   35.29   0.515152  66.9       432.0   opened    1
#                        2023-08-19 23:02:16.539977-04:00  2023-09-15  opened   26.87   0.503759  74.0       324.0   opened    1
# Short Put              2023-08-19 22:07:28.397743-04:00  2023-09-01  opened   69.83   0.544631  78.1       882.0   opened    1
#                                                          2023-09-08  opened   55.07   0.580161  78.1       554.0   opened    1
#                        2023-08-19 22:07:28.413387-04:00  2023-08-25  expred   100.00  0.722343  77.4       1665.0  expred    1
#                        2023-08-19 22:07:28.429017-04:00  2023-09-15  opened   43.62   0.536477  84.7       526.0   opened    1
#                        2023-08-19 23:01:57.185927-04:00  2023-09-01  opened   69.83   0.544631  81.3       882.0   opened    1
#                        2023-08-19 23:01:57.192928-04:00  2023-08-25  expred   100.00  0.722343  77.6       1665.0  expred    1
#                        2023-08-19 23:01:57.206894-04:00  2023-09-08  opened   55.07   0.580161  79.2       554.0   opened    1
#                        2023-08-19 23:01:57.220894-04:00  2023-09-15  opened   43.62   0.536477  84.2       526.0   opened    1
#                        2023-08-19 23:29:46.525262-04:00  2023-08-25  expred   100.00  0.722343  76.4       1665.0  expred    1
#                        2023-08-19 23:29:46.540884-04:00  2023-09-15  opened   43.62   0.536477  83.8       526.0   opened    1
#                        2023-08-19 23:29:46.567806-04:00  2023-09-08  opened   55.07   0.580161  80.4       554.0   opened    1
#                        2023-08-19 23:29:46.584808-04:00  2023-09-01  opened   69.83   0.544631  80.3       882.0   opened    1
# dtype: int64

# %%
for symbol in ml:
    print(symbol)
    print(df[(df['symbol']==symbol)].groupby(['strategy','exp_date','gain', 'pl']).size())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 for symbol in ml:
#       2     print(symbol)
#       3     print(df[(df['symbol']==symbol)].groupby(['strategy','exp_date','gain', 'pl']).size())
#
# NameError: name 'ml' is not defined

# %%
dd = df_single

print(dd.shape)

dd = dd[dd['status']=='opened']

print(dd.shape)

# %%
df.groupby(['strategy'])['pl'].sum()
# Out:
# strategy
# Credit Call Butterfly     0.0
# Credit Call Spread        0.0
# Credit Iron Condor        0.0
# Credit Put Butterfly      0.0
# Credit Put Spread         0.0
# Debit Call Butterfly      0.0
# Debit Iron Condor         0.0
# Debit Put Butterfly       0.0
# Debit Put Spread          0.0
# Iron Butterfly            0.0
# Long Call                 0.0
# Long Put                  0.0
# Reverse Iron Butterfly    0.0
# Name: pl, dtype: float64

# %%
ml = df['symbol'].unique()

#d4 = df[(df['strategy'] == st.CREDIT_IRON_CONDOR)] # | (df['strategy'] == st.CREDIT_PUT_SPREAD)]
d4 = df[df['exp_date'] < '2023-09-23']

print('symbol','\t win_count', '\t\t\t', 'loss_count', '\t\t', 'win_rate')
    
for symbol in ml:
    win_trade  = d4[(d4['symbol'] == symbol) & (d4['gain'] > 0)]# &(d4['status'] != 'opened')]
    loss_trade = d4[(d4['symbol'] == symbol) & (d4['gain'] < 0)]# &(d4['status'] == 'expr')]
    win_count  = win_trade.shape[0]
    loss_count = loss_trade.shape[0]
    win_total = win_trade['gain'].sum()   
    loss_total = loss_trade['gain'].sum()      
    if (win_count+loss_count) > 0:
        win_rate = win_count / (win_count+loss_count)
        print(symbol,'\t', win_count, '\t[%.2f]' % win_total, '\t\t', loss_count, '\t[%.2f]' % loss_total, '\t\t', '%.2f' % win_rate)
# Out:
# symbol 	 win_count 			 loss_count 		 win_rate
# AAPL 	 4 	[121.38] 		 7 	[-167.26] 		 0.36
# ABNB 	 4 	[758.44] 		 1 	[-98.31] 		 0.80
# AMAT 	 7 	[943.98] 		 3 	[-173.54] 		 0.70
# BLDR 	 3 	[161.43] 		 1 	[-88.72] 		 0.75
# ISRG 	 7 	[502.78] 		 2 	[-110.05] 		 0.78
# KLAC 	 3 	[189.11] 		 3 	[-196.17] 		 0.50
# MRVL 	 6 	[549.98] 		 4 	[-139.14] 		 0.60
# PLTR 	 3 	[106.05] 		 3 	[-95.14] 		 0.50
# PYPL 	 8 	[447.64] 		 5 	[-271.36] 		 0.62
# QCOM 	 6 	[244.97] 		 5 	[-272.84] 		 0.55
# SHOP 	 7 	[259.23] 		 3 	[-155.03] 		 0.70
# SWKS 	 11 	[2009.92] 		 1 	[-34.65] 		 0.92
# TSLA 	 3 	[211.89] 		 2 	[-165.93] 		 0.60
# ORCL 	 3 	[143.11] 		 3 	[-67.36] 		 0.50
# PANW 	 1 	[558.67] 		 2 	[-148.85] 		 0.33
# AMZN 	 4 	[366.29] 		 4 	[-381.36] 		 0.50
# ADBE 	 5 	[166.86] 		 0 	[0.00] 		 1.00
# AVGO 	 7 	[4048.12] 		 0 	[0.00] 		 1.00
# CMG 	 4 	[322.85] 		 1 	[-21.79] 		 0.80
# COST 	 8 	[628.08] 		 2 	[-95.95] 		 0.80
# DOCU 	 7 	[526.91] 		 4 	[-433.15] 		 0.64
# DPZ 	 7 	[537.60] 		 3 	[-180.21] 		 0.70
# ERF 	 1 	[7.41] 		 0 	[0.00] 		 1.00
# F 	 1 	[26.19] 		 1 	[-68.42] 		 0.50
# FTNT 	 7 	[548.44] 		 0 	[0.00] 		 1.00
# GOOGL 	 2 	[23.01] 		 4 	[-301.79] 		 0.33
# ILMN 	 3 	[279.72] 		 2 	[-199.75] 		 0.60
# MCD 	 6 	[360.37] 		 5 	[-222.34] 		 0.55
# META 	 5 	[345.99] 		 1 	[-38.61] 		 0.83
# MSFT 	 2 	[74.62] 		 2 	[-191.17] 		 0.50
# NVDA 	 3 	[171.65] 		 1 	[-16.61] 		 0.75
# PFE 	 4 	[134.81] 		 2 	[-129.80] 		 0.67
# PLUG 	 2 	[133.34] 		 1 	[-105.88] 		 0.67
# ROKU 	 5 	[434.30] 		 7 	[-622.84] 		 0.42
# SBUX 	 8 	[319.98] 		 2 	[-185.83] 		 0.80
# TSM 	 5 	[286.49] 		 5 	[-270.31] 		 0.50
# TWLO 	 6 	[406.47] 		 5 	[-282.12] 		 0.55
# UPST 	 7 	[315.74] 		 4 	[-193.93] 		 0.64
# V 	 4 	[158.71] 		 6 	[-331.36] 		 0.40
# BA 	 0 	[0.00] 		 1 	[-155.43] 		 0.00
# BAC 	 1 	[80.00] 		 1 	[-120.00] 		 0.50
# ETSY 	 2 	[49.69] 		 0 	[0.00] 		 1.00
# MU 	 1 	[88.89] 		 2 	[-172.85] 		 0.33
# NFLX 	 2 	[109.04] 		 0 	[0.00] 		 1.00
# SNOW 	 2 	[194.39] 		 1 	[-150.00] 		 0.67
# SPY 	 9 	[602.05] 		 10 	[-1472.72] 		 0.47
# SQ 	 3 	[198.52] 		 3 	[-149.26] 		 0.50
# TXN 	 3 	[104.86] 		 0 	[0.00] 		 1.00
# VEEV 	 1 	[95.40] 		 0 	[0.00] 		 1.00

# %%
df[df['exp_date']=='2023-09-15']['stop_reason']
# Out:
# 0          Days to expire 1 <= 1
# 6          Days to expire 1 <= 1
# 7       Stop Gain 94.00 >= 90.00
# 12     Stop Loss -88.72 >= 80.00
# 13      Stop Gain 98.20 >= 90.00
#                  ...
# 152        Days to expire 1 <= 1
# 159        Days to expire 1 <= 1
# 160        Days to expire 1 <= 1
# 161        Days to expire 1 <= 1
# 168        Days to expire 1 <= 1
# Name: stop_reason, Length: 138, dtype: object

# %%
# Out:
# 401849.0

# %%
df.shape[0]
# Out:
# 50

# %%
df.groupby('exp_date').count()
# Out:
#             symbol  strategy  credit  status  spread  open_price  breakeven_l
# exp_date
# 2023-09-15      28        28      28      28      17          28           25  \
# 2023-09-22      10        10      10      10       5          10            9
# 2023-09-29       9         9       9       9       3           9            8
# 2023-10-06       3         3       3       3       1           3            2
#
#             breakeven_h  max_profit  max_loss  ...  leg 3 exp_date
# exp_date                                       ...
# 2023-09-15           11          28        28  ...               8  \
# 2023-09-22            4          10        10  ...               3
# 2023-09-29            3           9         9  ...               2
# 2023-10-06            1           3         3  ...               0
#
#             leg 3 open_action  leg 3 quantity  leg 3 price  leg 4 otype
# exp_date
# 2023-09-15                  8               8            8            5  \
# 2023-09-22                  3               3            3            2
# 2023-09-29                  2               2            2            2
# 2023-10-06                  0               0            0            0
#
#             leg 4 strike  leg 4 exp_date  leg 4 open_action  leg 4 quantity
# exp_date
# 2023-09-15             5               5                  5               5  \
# 2023-09-22             2               2                  2               2
# 2023-09-29             2               2                  2               2
# 2023-10-06             0               0                  0               0
#
#             leg 4 price
# exp_date
# 2023-09-15            5
# 2023-09-22            2
# 2023-09-29            2
# 2023-10-06            0
#
# [4 rows x 57 columns]

# %%
df[['symbol', 'strategy', 'open_price', 'pnl', 'win_prob']]
# Out:
#    symbol              strategy  open_price       pnl  win_prob
# 0    ABNB     Credit Put Spread       1.035  0.526718      65.5
# 1    ABNB             Short Put       2.360  2.809524      70.8
# 2     ABT          Covered Call       0.610  1.016667      62.9
# 3     ABT     Credit Put Spread       1.025  0.518987      51.2
# 4    AVGO    Credit Iron Condor       3.625  0.568627      66.0
# 5    AVGO     Credit Put Spread       1.700  0.515152      75.5
# 6    AVGO     Credit Put Spread       1.800  0.562500      79.3
# 7    COST    Credit Iron Condor       1.695  0.512859      53.6
# 8    COST     Credit Put Spread       0.875  0.538462      65.5
# 9    COST    Credit Iron Condor       1.975  0.652893      58.6
# 10   COST     Credit Put Spread       1.725  0.526718      67.8
# 11   COST             Short Put       5.700  0.508929      74.3
# 12   COST    Credit Iron Condor       3.535  0.546790      67.4
# 13   COST             Short Put       7.675  0.539543      83.3
# 14    CRM    Credit Iron Condor       0.870  0.533742      53.7
# 15    CRM     Credit Put Spread       0.925  0.587302      73.1
# 16    CRM             Short Put       2.795  2.263158      77.2
# 17    CRM             Short Put       2.745  0.725231      83.9
# 18    CRM    Credit Iron Condor       1.700  0.515152      52.4
# 19   DOCU          Covered Call       2.475  0.511892      50.2
# 20   DOCU    Credit Iron Condor       1.740  0.533742      83.3
# 21   DOCU     Credit Put Spread       0.500  0.500000      75.0
# 22   DOCU             Short Put       1.305  0.699732      84.0
# 23   DOCU             Short Put       1.755  1.918033      69.5
# 24    DPZ             Short Put       5.500  1.724138      74.9
# 25      F     Credit Put Spread       0.335  0.503759      50.0
# 26      F     Credit Put Spread       0.170  0.515152      53.2
# 27   FTNT             Short Put       0.650  1.140351      60.0
# 28   MSFT             Short Put       2.555  1.377358      82.6
# 29   MSFT             Short Put       3.800  6.229508      83.1
# 30   MSFT             Short Put       3.175  0.509222      87.8
# 31   MSFT             Short Put       4.050  0.755597      88.3
# 32   QCOM  Credit Put Butterfly       3.680  0.691729      52.5
# 33   QCOM     Credit Put Spread       0.360  0.562500      57.1
# 34   QCOM             Short Put       1.350  0.627907      64.0
# 35   QCOM    Credit Iron Condor       2.670  0.500938      53.5
# 36   QCOM             Short Put       1.930  1.229299      62.6
# 37   QCOM             Short Put       2.330  1.991453      58.8
# 38   SNOW  Credit Put Butterfly       3.625  0.568627      69.0
# 39   SNOW     Credit Put Spread       1.855  0.589825      55.9
# 40   SNOW             Short Put       3.575  0.638963      60.1
# 41   SNOW     Credit Put Spread       1.725  0.526718      60.3
# 42   SNOW             Short Put       4.575  0.644820      65.2
# 43     SQ          Covered Call       1.440  0.746114      54.9
# 44     SQ  Credit Put Butterfly       2.330  0.872659      60.4
# 45     SQ        Iron Butterfly       3.045  0.558203      72.2
# 46     SQ          Covered Call       1.495  0.520000      64.7
# 47     SQ  Credit Put Butterfly       3.530  1.017291      63.3
# 48     SQ          Covered Call       1.905  0.772819      62.4
# 49     SQ          Covered Call       2.750  4.435484      57.2

# %%
account = dennis_weekly_trade


opt = account.get_position_summary()
print('summary', opt.shape[0])
pos = account.get_positions()
print('positions', pos.shape[0])
trx = account.get_transactions()
print('trax', trx.shape[0])

from datetime import datetime

today = datetime.now().date()      

opt['days_to_expire'] = opt.apply(lambda x: (pd.Timestamp(x['exp_date']).date()-today).days if x['exp_date'] != None else x['exp_date'], axis = 1)  

opt['amount'] = opt.apply(lambda x: x['last_price'] * x['quantity'], axis = 1)  

opt['amount'] = opt.apply(lambda x: x['amount'] * 100 if x['strategy'] != 'Unpaired' else x['amount'], axis = 1)  

opt['amount'] = opt.apply(lambda x: -1 * x['amount'] if x['credit'] == 'True' else x['amount'], axis = 1)  

cash_position = account.get_BuyingPower()
print('cash position', round(cash_position,2))
margin_position = account.get_margin_position()
print('margin position', margin_position)
asset_value = opt['amount'].sum()
account_value = cash_position + margin_position + asset_value
print('asset value', asset_value)
print('account value', round(account_value,2))
print('PL', opt['pl'].sum())
# Out:
# summary 1
# positions 3
# trax 1
# cash position 99088.56
# margin position 0.0
# asset value 911.44
# account value 100000.0
# PL 0.0

# %%
opt[opt['status']=='opened']['amount'].sum()
# Out:
# 911.44

# %%
print(opt.groupby('strategy')['strategy'].count())
print(opt.groupby('symbol')['symbol'].count())
print(opt.groupby('exp_date')['exp_date'].count())
# Out:
# strategy
# Credit Iron Condor      47
# Credit Put Butterfly    51
# Credit Put Spread       61
# Iron Butterfly          19
# Unpaired                 2
# Name: strategy, dtype: int64
# symbol
# ADBE      8
# AMZN     11
# CMG       8
# COST      8
# DOCU     14
# DPZ      10
# ETSY      2
# FTNT      2
# GOOGL    10
# ILMN      2
# MCD      13
# META      8
# MSFT      7
# PFE       7
# ROKU     11
# SBUX     12
# SQ        5
# TSM      13
# TWLO     11
# UPST      9
# V         9
# Name: symbol, dtype: int64
# exp_date
# 2023-09-15    44
# 2023-09-22    49
# 2023-09-29    45
# 2023-10-06    40
# Name: exp_date, dtype: int64

# %%
print('total PL', opt['pl'].sum())
print('win%', round(100 * opt[opt['pl'] > 0].shape[0] / opt.shape[0],2))
print('loss%', round(100 * opt[opt['pl'] < 0].shape[0] / opt.shape[0],2))
# Out:
# total PL 68.0
# win% 16.11
# loss% 12.22

# %%
opt[opt['pl']!=0][['symbol', 'strategy', 'open_price', 'last_price', 'pl', 'credit']]
# Out:
#     symbol              strategy  open_price  last_price    pl credit
# 8     AMZN  Credit Put Butterfly        2.83        2.82   4.0   True
# 12    AMZN     Credit Put Spread        0.71        0.70  19.0   True
# 13    AMZN  Credit Put Butterfly        3.44        3.45  -3.0   True
# 19     CMG    Credit Iron Condor        4.58        4.57   4.0   True
# 23    COST    Credit Iron Condor        1.75        1.74   7.0   True
# ..     ...                   ...         ...         ...   ...    ...
# 165     SQ        Iron Butterfly        4.09        4.10  -5.0   True
# 169    TSM    Credit Iron Condor        3.28        3.29  -4.0   True
# 173   TWLO    Credit Iron Condor        3.46        3.47  -3.0   True
# 178      V  Credit Put Butterfly        4.46        4.47  -4.0   True
# 179      V     Credit Put Spread        0.88        0.87  15.0   True
#
# [68 rows x 6 columns]

# %%
df.groupby('exp

# %%
# Out:
# Index(['symbol', 'strategy', 'credit', 'status', 'exp_date', 'spread',
#        'open_price', 'breakeven_l', 'breakeven_h', 'max_profit', 'max_loss',
#        'pnl', 'win_prob', 'last_win_prob', 'trade_date', 'earning_date',
#        'trade_stock_price', 'margin', 'quantity', 'last_quote_date',
#        'last_stock_price', 'exp_stock_price', 'last_price', 'exp_price', 'pl',
#        'gain', 'stop_price', 'stop_date', 'stop_reason', 'order_id', 'uuid',
#        'legs_desc', 'target_low', 'target_high', 'open_cash', 'open_margin',
#        'close_cash', 'close_margin', 'cash_position', 'margin_position',
#        'leg 1 otype', 'leg 1 strike', 'leg 1 exp_date', 'leg 1 open_action',
#        'leg 1 quantity', 'leg 1 price', 'leg 2 otype', 'leg 2 strike',
#        'leg 2 exp_date', 'leg 2 open_action', 'leg 2 quantity', 'leg 2 price',
#        'leg 3 otype', 'leg 3 strike', 'leg 3 exp_date', 'leg 3 open_action',
#        'leg 3 quantity', 'leg 3 price', 'leg 4 otype', 'leg 4 strike',
#        'leg 4 exp_date', 'leg 4 open_action', 'leg 4 quantity', 'leg 4 price'],
#       dtype='object')

# %%
opt
# Out:
#     symbol              strategy credit  status    exp_date  spread
# 0     ETSY              Unpaired  False  opened        None     NaN  \
# 1     ADBE    Credit Iron Condor   True  opened  2023-09-22     5.0
# 2     ADBE     Credit Put Spread   True  opened  2023-09-22     2.5
# 3     ADBE    Credit Iron Condor   True  opened  2023-09-29    10.0
# 4     ADBE     Credit Put Spread   True  opened  2023-09-29    10.0
# ..     ...                   ...    ...     ...         ...     ...
# 175   UPST     Credit Put Spread   True  opened  2023-09-15     1.0
# 176   UPST        Iron Butterfly   True  opened  2023-09-15     7.0
# 177      V    Credit Iron Condor   True  opened  2023-09-15     5.0
# 178      V  Credit Put Butterfly   True  opened  2023-09-15    10.0
# 179      V     Credit Put Spread   True  opened  2023-09-15     2.5
#
#      open_price  breakeven_l  breakeven_h  max_profit  ...  leg 3 exp_date
# 0     67.129997          NaN          NaN         NaN  ...             NaN  \
# 1      1.820000      528.180      616.820        1.82  ...      2023-09-22
# 2      1.050000      536.450          NaN        1.05  ...             NaN
# 3      3.380000      526.620      633.380        3.38  ...      2023-09-29
# 4      3.400000      541.600          NaN        3.40  ...             NaN
# ..          ...          ...          ...         ...  ...             ...
# 175    0.340000       29.165          NaN        0.34  ...             NaN
# 176    2.530000       25.530       34.470        2.53  ...      2023-09-15
# 177    1.940000      240.555      249.445        1.94  ...      2023-09-15
# 178    4.460000      236.965      248.035        4.46  ...      2023-09-15
# 179    0.880000      246.625          NaN        0.88  ...             NaN
#
#      leg 3 open_action  leg 3 quantity  leg 3 price leg 4 otype leg 4 strike
# 0                  NaN             NaN          NaN         NaN          NaN  \
# 1          buy_to_open             7.0        3.030        call        615.0
# 2                  NaN             NaN          NaN         NaN          NaN
# 3          buy_to_open             3.0        2.135        call        630.0
# 4                  NaN             NaN          NaN         NaN          NaN
# ..                 ...             ...          ...         ...          ...
# 175                NaN             NaN          NaN         NaN          NaN
# 176       sell_to_open             5.0        1.605        call         37.0
# 177        buy_to_open             8.0        0.275        call        247.5
# 178       sell_to_open             4.0        5.350         NaN          NaN
# 179                NaN             NaN          NaN         NaN          NaN
#
#      leg 4 exp_date  leg 4 open_action  leg 4 quantity leg 4 price
# 0               NaN                NaN             NaN         NaN
# 1        2023-09-22       sell_to_open             7.0       3.675
# 2               NaN                NaN             NaN         NaN
# 3        2023-09-29       sell_to_open             3.0       2.965
# 4               NaN                NaN             NaN         NaN
# ..              ...                ...             ...         ...
# 175             NaN                NaN             NaN         NaN
# 176      2023-09-15        buy_to_open             5.0       0.090
# 177      2023-09-15       sell_to_open             8.0       1.885
# 178             NaN                NaN             NaN         NaN
# 179             NaN                NaN             NaN         NaN
#
# [180 rows x 64 columns]

# %%
from datetime import datetime

today = datetime.now().date()      

opt['days_to_expire'] = opt.apply(lambda x: (pd.Timestamp(x['exp_date']).date()-today).days if x['exp_date'] != None else x['exp_date'], axis = 1)  

opt['amount'] = opt.apply(lambda x: x['last_price'] * x['quantity'], axis = 1)  

opt['amount'] = opt.apply(lambda x: x['amount'] * 100 if x['strategy'] != 'Unpaird' else x['amount'], axis = 1)  

opt['amount'] = opt.apply(lambda x: -1 * x['amount'] if x['credit'] == 'True' else x['amount'], axis = 1)  

opt['amount']
# Out:
# 0      93982.0
# 1      -1274.0
# 2      -1785.0
# 3      -1014.0
# 4      -1020.0
#         ...
# 175    -1258.0
# 176    -1265.0
# 177    -1552.0
# 178    -1788.0
# 179    -1305.0
# Name: amount, Length: 180, dtype: float64

# %%
opt['credit'][0] == 'True'
# Out:
# False

# %%
account = jihuang
account_list = account.get_account_list()

# %%
df = pd.DataFrame()

for account_name in account_list:
    acct = account.get_account(account_name)
    d = acct.get_account_history().tail(1)
    d.insert(0, 'account name', account_name)
    df = pd.concat([df, d])
    
df[['account name', 'account value', 'asset value', 'cash position', 'margin position', 'Profit/Loss' ]]
# Out:
#   account name  account value  asset value  cash position  margin position
# 0       winwin      1000034.5    -256495.0       677964.5         578565.0  \
#
#    Profit/Loss
# 0         75.0

# %%
acct = account.get_account('winwin')

# %%
pos = acct.get_position_summary()

pos.columns
# Out:
# Index(['symbol', 'strategy', 'credit', 'status', 'exp_date', 'spread',
#        'open_price', 'breakeven_l', 'breakeven_h', 'max_profit', 'max_loss',
#        'pnl', 'win_prob', 'last_win_prob', 'trade_date', 'earning_date',
#        'trade_stock_price', 'margin', 'quantity', 'last_quote_date',
#        'last_stock_price', 'exp_stock_price', 'last_price', 'exp_price', 'pl',
#        'gain', 'stop_price', 'stop_date', 'stop_reason', 'order_id', 'uuid',
#        'legs_desc', 'target_low', 'target_high', 'open_cash', 'open_margin',
#        'close_cash', 'close_margin', 'cash_position', 'margin_position',
#        'leg 1 otype', 'leg 1 strike', 'leg 1 exp_date', 'leg 1 open_action',
#        'leg 1 quantity', 'leg 1 price', 'leg 2 otype', 'leg 2 strike',
#        'leg 2 exp_date', 'leg 2 open_action', 'leg 2 quantity', 'leg 2 price',
#        'leg 3 otype', 'leg 3 strike', 'leg 3 exp_date', 'leg 3 open_action',
#        'leg 3 quantity', 'leg 3 price', 'leg 4 otype', 'leg 4 strike',
#        'leg 4 exp_date', 'leg 4 open_action', 'leg 4 quantity', 'leg 4 price'],
#       dtype='object')

# %%
x = pos[['symbol', 'strategy', 'exp_date', 'gain', 'last_win_prob', 'last_price']]
x.to_html()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 x = pos[['symbol', 'strategy', 'exp_date', 'gain', 'last_win_prob', 'last_price']]
#       2 x.to_html()
#
# NameError: name 'pos' is not defined

# %%
spread.get_position_summary()['last_quote_date']
# Out:
# 0      2023-09-11 01:55:33 EDT
# 1      2023-09-11 01:55:33 EDT
# 2      2023-09-11 01:55:33 EDT
# 3      2023-09-11 01:55:33 EDT
# 4      2023-09-11 01:55:33 EDT
#                 ...
# 145    2023-09-11 01:55:33 EDT
# 146    2023-09-11 01:55:33 EDT
# 147    2023-09-11 01:55:33 EDT
# 148    2023-09-11 01:55:33 EDT
# 149    2023-09-11 01:55:33 EDT
# Name: last_quote_date, Length: 150, dtype: object

# %%
spread_df = spread.get_position_summary()

spread_df.columns
# Out:
# Index(['symbol', 'strategy', 'credit', 'status', 'exp_date', 'spread',
#        'open_price', 'breakeven_l', 'breakeven_h', 'max_profit', 'max_loss',
#        'pnl', 'win_prob', 'last_win_prob', 'trade_date', 'earning_date',
#        'trade_stock_price', 'margin', 'quantity', 'last_quote_date',
#        'last_stock_price', 'exp_stock_price', 'last_price', 'exp_price', 'pl',
#        'gain', 'stop_price', 'stop_date', 'stop_reason', 'order_id', 'uuid',
#        'legs_desc', 'target_low', 'target_high', 'open_cash', 'open_margin',
#        'close_cash', 'close_margin', 'cash_position', 'margin_position',
#        'leg 1 otype', 'leg 1 strike', 'leg 1 exp_date', 'leg 1 open_action',
#        'leg 1 quantity', 'leg 1 price', 'leg 2 otype', 'leg 2 strike',
#        'leg 2 exp_date', 'leg 2 open_action', 'leg 2 quantity', 'leg 2 price'],
#       dtype='object')

# %%
monitor_df = mysite.get_monitor_df()
monitor_df
# Out:
#    symbol  last_price  support  resistence rating       trend  slope  bb_pos
# 0    MSFT      331.77   331.37      350.73    1.8  increasing   0.50    1.02  \
# 1    AAPL      176.30   190.97      197.96    2.0    no trend   0.06    0.45
# 2   GOOGL      135.34   116.10      126.43    1.8  increasing   0.27    0.86
# 3    NFLX      434.69   398.15      485.00    2.1  increasing   0.65    0.82
# 4    META      301.66   304.71      316.24    1.8  decreasing  -0.36    0.98
# ..    ...         ...      ...         ...    ...         ...    ...     ...
# 76     GS      330.90   345.74      358.63    2.3  decreasing  -0.84    0.53
# 77  BRK-B      367.78   359.26         NaN    2.7    no trend   0.19    0.98
# 78      V      247.30   215.73      234.67    1.8  increasing   0.34    0.80
# 79    JNJ      163.58   170.38      174.10    2.4  decreasing  -0.55    0.37
# 80    DIS       83.68    79.75       87.96    2.2  decreasing  -0.36    0.32
#
#                                               bb_link    rsi  ... delta4
# 0   C:\Users\jimhu\option_trader\data\charts/MSFT_...  61.29  ...  0.501  \
# 1   C:\Users\jimhu\option_trader\data\charts/AAPL_...  44.67  ...  0.499
# 2   C:\Users\jimhu\option_trader\data\charts/GOOGL...  65.39  ...  0.500
# 3   C:\Users\jimhu\option_trader\data\charts/NFLX_...  59.05  ...  0.501
# 4   C:\Users\jimhu\option_trader\data\charts/META_...  59.17  ...  0.500
# ..                                                ...    ...  ...    ...
# 76  C:\Users\jimhu\option_trader\data\charts/GS_BB...  45.59  ...  0.499
# 77  C:\Users\jimhu\option_trader\data\charts/BRK-B...  68.73  ...  0.501
# 78  C:\Users\jimhu\option_trader\data\charts/V_BB.png  62.04  ...  0.501
# 79  C:\Users\jimhu\option_trader\data\charts/JNJ_B...  45.64  ...  0.498
# 80  C:\Users\jimhu\option_trader\data\charts/DIS_B...  41.79  ...    NaN
#
#                  quote_time 10 days change %          last_update_time   IV1%
# 0   2023-09-12 16:30:04 EDT             2.43  Tue Sep 12 13:30:05 2023  21.25  \
# 1   2023-09-12 16:30:08 EDT            -2.21  Tue Sep 12 13:30:09 2023 -10.00
# 2   2023-09-12 16:30:12 EDT             3.20  Tue Sep 12 13:30:13 2023  30.00
# 3   2023-09-12 16:30:16 EDT             3.83  Tue Sep 12 13:30:18 2023   1.82
# 4   2023-09-12 16:30:20 EDT             3.78  Tue Sep 12 13:30:22 2023  32.86
# ..                      ...              ...                       ...    ...
# 76  2023-09-12 16:35:53 EDT             2.30  Tue Sep 12 13:35:54 2023  19.38
# 77  2023-09-12 16:35:57 EDT             3.33  Tue Sep 12 13:35:58 2023  32.00
# 78  2023-09-12 16:36:01 EDT             1.40  Tue Sep 12 13:36:02 2023  13.33
# 79  2023-09-12 16:36:05 EDT            -0.43  Tue Sep 12 13:36:06 2023  10.62
# 80  2023-09-12 16:36:09 EDT            -0.57  Tue Sep 12 13:36:10 2023    NaN
#
#      IV2%    IV3%   IV4%  10 days max  10 days min
# 0   36.25 -100.00  42.50       338.42       321.72
# 1    2.61    0.43  -0.43       189.98       173.54
# 2   32.50   35.00  37.00       138.00       130.14
# 3    1.82    5.45   5.45       453.45       413.27
# 4   27.86   27.14  35.00       309.04       285.80
# ..    ...     ...    ...          ...          ...
# 76  35.00 -100.00  37.50       331.91       318.68
# 77  40.00   52.00  60.00       366.61       354.01
# 78  25.00   34.17  42.50       248.87       242.60
# 79   3.75    6.25   8.12       166.21       157.35
# 80    NaN     NaN    NaN        84.69        79.75
#
# [81 rows x 38 columns]

# %%
spread_df.join()

inner_joined = spread_df.join(
    on=["symbol"],
    how="inner",
    lsuffix="_x",
    rsuffix="_y",
)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[57], line 1
# ----> 1 spread_df.join()
#       3 inner_joined = spread_df.join(
#       4     on=["symbol"],
#       5     how="inner",
#       6     lsuffix="_x",
#       7     rsuffix="_y",
#       8 )
#
# TypeError: DataFrame.join() missing 1 required positional argument: 'other'

# %%
x = spread_df.join(monitor_df, lsuffix="", rsuffix="_right", how='inner')

# %%
x.columns
# Out:
# Index(['symbol', 'strategy', 'credit', 'status', 'exp_date', 'spread',
#        'open_price', 'breakeven_l', 'breakeven_h', 'max_profit', 'max_loss',
#        'pnl', 'win_prob', 'last_win_prob', 'trade_date', 'earning_date',
#        'trade_stock_price', 'margin', 'quantity', 'last_quote_date',
#        'last_stock_price', 'exp_stock_price', 'last_price', 'exp_price', 'pl',
#        'gain', 'stop_price', 'stop_date', 'stop_reason', 'order_id', 'uuid',
#        'legs_desc', 'target_low', 'target_high', 'open_cash', 'open_margin',
#        'close_cash', 'close_margin', 'cash_position', 'margin_position',
#        'leg 1 otype', 'leg 1 strike', 'leg 1 exp_date', 'leg 1 open_action',
#        'leg 1 quantity', 'leg 1 price', 'leg 2 otype', 'leg 2 strike',
#        'leg 2 exp_date', 'leg 2 open_action', 'leg 2 quantity', 'leg 2 price',
#        'symbol_right', 'last_price_right', 'support', 'resistence', 'rating',
#        'trend', 'slope', 'bb_pos', 'bb_link', 'rsi', 'rsi_link', 'macd',
#        'macd_link', 'mfi', 'mfi_link', 'earning', 'day_range_pos',
#        'fifty_weeks_range_pos', 'volume_range_pos', 'forward_PE', 'HV', 'IV1',
#        'delta1', 'IV2', 'delta2', 'IV3', 'delta3', 'IV4', 'delta4',
#        'quote_time', '10 days change %', 'last_update_time', 'IV1%', 'IV2%',
#        'IV3%', 'IV4%', '10 days max', '10 days min'],
#       dtype='object')

# %%
account_list = jihuang.get_account_list()
account_list
# Out:
# ['BrokerageLink (651089915)',
#  'Individual - TOD (X86311120)',
#  'Traditional IRA (225521616)',
#  'winwin']

# %%
history_df = pd.DataFrame()

position_df = pd.DataFrame()

account_name = 'BrokerageLink (651089915)'

acct = jihuang.get_account(account_name)
acct.create_daily_account_summary()            
init_balance = acct.get_initial_balance()
history_df = acct.get_account_history().tail(1)
position_df = acct.get_position_summary(status='opened')
history_df.insert(0, 'account name', account_name)
position_df.insert(0, 'account name', account_name) 
history_df.at[position_df.index[0], 'Gain %'] =  round(100 * (history_df.at[history_df.index[0], 'account value'] - init_balance)/ init_balance, 2)       

stock_position = position_df[position_df['strategy'] =='Unpaired'][['symbol', 'last_stock_price', 'gain']] 

stock_position
# Out:
#    symbol  last_stock_price    gain
# 0    ADBE            541.84    2.78
# 1     AMD            105.39  -11.93
# 4     ALK             40.42  -28.46
# 5   GOOGL            135.34    0.19
# 6    AMZN            141.26   21.06
# 7    AAPL            175.60   21.63
# 10   AVGO            843.51  187.46
# 11   BLDR            135.75    0.13
# 12    CUK             13.77   57.25
# 13   COIN             81.04  -62.89
# 14   COST            558.18   20.80
# 15    DIS             83.43   -1.01
# 16   DOCU             46.46  -54.56
# 17    ERF             17.61   24.10
# 18   ETSY             65.14  -55.88
# 19   META            301.62   -2.02
# 20      F             12.44  -10.50
# 23   ISRG            301.39   56.47
# 25   MRVL             55.84   77.83
# 26   MEDP            278.47   67.98
# 27   NFLX            434.88   20.07
# 29    NKE             96.37  -32.04
# 30   NVDA            449.04   32.94
# 33   PLTR             15.62  -39.92
# 35   PTON              5.43  -94.99
# 36   PINS             27.90  -59.06
# 37   TQQQ             40.52   77.72
# 38   QCOM            111.30   79.03
# 40     QS              7.10  -43.55
# 41   ROKU             81.73  -41.35
# 42    CRM            221.69    2.97
# 43     SQ             54.55  -47.97
# 44    TSM             90.64   72.26
# 45   TSLA            267.35  -10.36
# 47   PATH             18.83   44.96
# 48   UPST             31.36  -84.64

# %%
#https://thepythoncode.com/article/use-gmail-api-in-python

import os
import pickle
# Gmail API utils
from googleapiclient.discovery import build
from google_auth_oauthlib.flow import InstalledAppFlow
from google.auth.transport.requests import Request
# for encoding/decoding messages in base64
from base64 import urlsafe_b64decode, urlsafe_b64encode
# for dealing with attachement MIME types
from email.mime.text import MIMEText
from email.mime.multipart import MIMEMultipart
from email.mime.image import MIMEImage
from email.mime.audio import MIMEAudio
from email.mime.base import MIMEBase
from mimetypes import guess_type as guess_mime_type

# Request all access (permission to read/send/receive emails, manage the inbox, and more)
SCOPES = ['https://mail.google.com/']
our_email = 'jim.huang.bellevue@gmail.com'

# %%
def gmail_authenticate():
    creds = None
    # the file token.pickle stores the user's access and refresh tokens, and is
    # created automatically when the authorization flow completes for the first time
    if os.path.exists("token.pickle"):
        with open("token.pickle", "rb") as token:
            creds = pickle.load(token)
    # if there are no (valid) credentials availablle, let the user log in.
    if not creds or not creds.valid:
        if creds and creds.expired and creds.refresh_token:
            creds.refresh(Request())
        else:
            flow = InstalledAppFlow.from_client_secrets_file('C:/Users/jimhu/option_trader/credentials.json', SCOPES)
            creds = flow.run_local_server(port=0)
        # save the credentials for the next run
        with open("token.pickle", "wb") as token:
            pickle.dump(creds, token)
    return build('gmail', 'v1', credentials=creds)

# get the Gmail API service
service = gmail_authenticate()
# Out:
# Please visit this URL to authorize this application: https://accounts.google.com/o/oauth2/auth?response_type=code&client_id=844605684221-8o8t98bje2mbkr8n6uuqc9k0utgfr7uv.apps.googleusercontent.com&redirect_uri=http%3A%2F%2Flocalhost%3A56363%2F&scope=https%3A%2F%2Fmail.google.com%2F&state=XWYlBgGNXKbmBc2SUF3OoUnxqMq29J&access_type=offline

# %%
def search_messages(service, query):
    result = service.users().messages().list(userId='me',q=query).execute()
    messages = [ ]
    if 'messages' in result:
        messages.extend(result['messages'])
    while 'nextPageToken' in result:
        page_token = result['nextPageToken']
        result = service.users().messages().list(userId='me',q=query, pageToken=page_token).execute()
        if 'messages' in result:
            messages.extend(result['messages'])
    return messages

# %%
# utility functions
def get_size_format(b, factor=1024, suffix="B"):
    """
    Scale bytes to its proper byte format
    e.g:
        1253656 => '1.20MB'
        1253656678 => '1.17GB'
    """
    for unit in ["", "K", "M", "G", "T", "P", "E", "Z"]:
        if b < factor:
            return f"{b:.2f}{unit}{suffix}"
        b /= factor
    return f"{b:.2f}Y{suffix}"


def clean(text):
    # clean text for creating a folder
    return "".join(c if c.isalnum() else "_" for c in text)

# %%
def parse_parts(service, parts, folder_name, message):
    """
    Utility function that parses the content of an email partition
    """
    if parts:
        for part in parts:
            filename = part.get("filename")
            mimeType = part.get("mimeType")
            body = part.get("body")
            data = body.get("data")
            file_size = body.get("size")
            part_headers = part.get("headers")
            if part.get("parts"):
                # recursively call this function when we see that a part
                # has parts inside
                parse_parts(service, part.get("parts"), folder_name, message)
            if mimeType == "text/plain":
                # if the email part is text plain
                if data:
                    text = urlsafe_b64decode(data).decode()
                    print(text)
            elif mimeType == "text/html":
                # if the email part is an HTML content
                # save the HTML file and optionally open it in the browser
                if not filename:
                    filename = "index.html"
                filepath = os.path.join(folder_name, filename)
                print("Saving HTML to", filepath)
                with open(filepath, "wb") as f:
                    f.write(urlsafe_b64decode(data))
            else:
                # attachment other than a plain text or HTML
                for part_header in part_headers:
                    part_header_name = part_header.get("name")
                    part_header_value = part_header.get("value")
                    if part_header_name == "Content-Disposition":
                        if "attachment" in part_header_value:
                            # we get the attachment ID 
                            # and make another request to get the attachment itself
                            print("Saving the file:", filename, "size:", get_size_format(file_size))
                            attachment_id = body.get("attachmentId")
                            attachment = service.users().messages() \
                                        .attachments().get(id=attachment_id, userId='me', messageId=message['id']).execute()
                            data = attachment.get("data")
                            filepath = os.path.join(folder_name, filename)
                            if data:
                                with open(filepath, "wb") as f:
                                    f.write(urlsafe_b64decode(data))

# %%
def read_message(service, message):
    """
    This function takes Gmail API `service` and the given `message_id` and does the following:
        - Downloads the content of the email
        - Prints email basic information (To, From, Subject & Date) and plain/text parts
        - Creates a folder for each email based on the subject
        - Downloads text/html content (if available) and saves it under the folder created as index.html
        - Downloads any file that is attached to the email and saves it in the folder created
    """
    msg = service.users().messages().get(userId='me', id=message['id'], format='full').execute()
    # parts can be the message body, or attachments
    payload = msg['payload']
    headers = payload.get("headers")
    parts = payload.get("parts")
    folder_name = "email"
    has_subject = False
    if headers:
        # this section prints email basic info & creates a folder for the email
        for header in headers:
            name = header.get("name")
            value = header.get("value")
            if name.lower() == 'from':
                # we print the From address
                print("From:", value)
            if name.lower() == "to":
                # we print the To address
                print("To:", value)
            if name.lower() == "subject":
                # make our boolean True, the email has "subject"
                has_subject = True
                # make a directory with the name of the subject
                folder_name = clean(value)
                # we will also handle emails with the same subject name
                folder_counter = 0
                while os.path.isdir(folder_name):
                    folder_counter += 1
                    # we have the same folder name, add a number next to it
                    if folder_name[-1].isdigit() and folder_name[-2] == "_":
                        folder_name = f"{folder_name[:-2]}_{folder_counter}"
                    elif folder_name[-2:].isdigit() and folder_name[-3] == "_":
                        folder_name = f"{folder_name[:-3]}_{folder_counter}"
                    else:
                        folder_name = f"{folder_name}_{folder_counter}"
                os.mkdir(folder_name)
                print("Subject:", value)
            if name.lower() == "date":
                # we print the date when the message was sent
                print("Date:", value)
    if not has_subject:
        # if the email does not have a subject, then make a folder with "email" name
        # since folders are created based on subjects
        if not os.path.isdir(folder_name):
            os.mkdir(folder_name)
    parse_parts(service, parts, folder_name, message)
    print("="*50)

# %%
# get emails that match the query you specify
results = search_messages(service, "親愛的保戶您好")
print(f"Found {len(results)} results.")
# for each email matched, read it (output plain/text to console & save HTML and attachments)
for msg in results:
    read_message(service, msg)
# Out:
# Found 1 results.
# From: "新安東京海上產險" <isurvey@tmnewa.com.tw>
# To: <jim.huang.bellevue@gmail.com>
# Date: Mon, 11 Sep 2023 12:02:18 +0800
# Subject: 新安東京海上產物保險-汽車保險電子保單00012V8177749-01[車號**D-0182]
# Saving HTML to 新安東京海上產物保險_汽車保險電子保單00012V8177749_01_車號__D_0182_\index.html
# Saving the file: P17CAR_00012V8177749_2023.pdf size: 2.85MB
# ==================================================

# %%
def highlight(row):
    if row['revenue'] > 500:
        return ['background-color: red'] * len(row)
    else:
        return [''] * len(row)

s = df.style.apply(highlight, axis=1)
s = s.set_table_styles([
    {
        'selector': '.col_heading',
        'props': 'background-color: yellow; color: black;'
    }
])

s.to_html('output.html')

# %%
monitor_df = mysite.get_monitor_df()[['symbol', 'last_price', '10 days min', '10 days max', 'IV1%', 'earning']]
monitor_df['10 days range'] = monitor_df.apply(lambda x: (x['last_price']-x['10 days min']) / (x['10 days max']-x['10 days min']), axis = 1)

# %%
monitor_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 monitor_df
#
# NameError: name 'monitor_df' is not defined

# %%
d4[d4['exp_date'] == '2023-09-15'][['symbol', 'strategy', 'stop_date', 'trade_stock_price', 'last_price', 'exp_price']]
# Out:
#     symbol                strategy                stop_date
# 0     AAPL               Long Call  2023-09-13 15:07:23 EDT  \
# 22    COST       Credit Put Spread  2023-09-13 15:07:33 EDT
# 34     DPZ      Credit Call Spread  2023-09-13 15:07:33 EDT
# 21    COST      Credit Call Spread  2023-09-11 15:02:53 EDT
# 20    KLAC               Long Call  2023-09-13 15:07:23 EDT
# ..     ...                     ...                      ...
# 21    AVGO  Reverse Iron Butterfly  2023-09-13 15:06:11 EDT
# 78    QCOM       Debit Iron Condor  2023-09-13 15:07:13 EDT
# 125   TSLA        Debit Put Spread  2023-09-11 12:18:53 EDT
# 23    BLDR  Reverse Iron Butterfly  2023-09-13 15:06:11 EDT
# 74    PYPL       Debit Iron Condor  2023-09-12 11:02:11 EDT
#
#      trade_stock_price  last_price exp_price
# 0           178.179993       12.68      None
# 22          551.190002        0.56      None
# 34          387.369995        3.25      None
# 21          551.190002        1.63      None
# 20          497.730011        5.75      None
# ..                 ...         ...       ...
# 21          857.549988        4.97       NaN
# 78          106.139999        0.93       NaN
# 125         248.500000        0.20       NaN
# 23          139.889999        7.50       NaN
# 74           60.980000        2.06       NaN
#
# [138 rows x 6 columns]

# %%
# Out:
# Index(['symbol', 'strategy', 'credit', 'status', 'exp_date', 'spread',
#        'open_price', 'breakeven_l', 'breakeven_h', 'max_profit', 'max_loss',
#        'pnl', 'win_prob', 'last_win_prob', 'trade_date', 'earning_date',
#        'trade_stock_price', 'margin', 'quantity', 'last_quote_date',
#        'last_stock_price', 'exp_stock_price', 'last_price', 'exp_price', 'pl',
#        'gain', 'stop_price', 'stop_date', 'stop_reason', 'order_id', 'uuid',
#        'legs_desc', 'target_low', 'target_high', 'open_cash', 'open_margin',
#        'close_cash', 'close_margin', 'cash_position', 'margin_position',
#        'leg 1 otype', 'leg 1 strike', 'leg 1 exp_date', 'leg 1 open_action',
#        'leg 1 quantity', 'leg 1 price', 'leg 2 otype', 'leg 2 strike',
#        'leg 2 exp_date', 'leg 2 open_action', 'leg 2 quantity', 'leg 2 price',
#        'leg 3 otype', 'leg 3 strike', 'leg 3 exp_date', 'leg 3 open_action',
#        'leg 3 quantity', 'leg 3 price', 'leg 4 otype', 'leg 4 strike',
#        'leg 4 exp_date', 'leg 4 open_action', 'leg 4 quantity', 'leg 4 price',
#        'days_to_expire', 'amount'],
#       dtype='object')

# %%
dfc[['symbol', 'strategy', 'last_stock_price', 'target_low', 'target_high', 'gain', 'win_prob', 'pnl']]
# Out:
#     symbol               strategy  last_stock_price  target_low  target_high
# 0     AAPL              Long Call            174.55      174.00       189.70  \
# 95    QCOM    Debit Put Butterfly            112.33      106.40       116.55
# 53   GOOGL  Credit Call Butterfly            136.24      127.46       136.17
# 47    FTNT  Credit Call Butterfly             65.15       57.16        63.17
# 42     DPZ   Credit Put Butterfly            393.19      378.83       398.40
# ..     ...                    ...               ...         ...          ...
# 257     BA      Credit Put Spread            187.45      202.37       228.85
# 259    BAC      Credit Put Spread             26.63       28.13        29.20
# 389    PFE     Credit Call Spread             33.92       32.10        35.90
# 248    TGT   Credit Put Butterfly            106.04      119.34       126.95
# 247    TGT  Credit Call Butterfly            105.46      119.34       126.95
#
#        gain  win_prob   pnl
# 0    -19.75      54.8  0.72
# 95     6.35      57.9  0.76
# 53     1.39      64.6  0.56
# 47    97.37      93.5  1.73
# 42    92.36      93.2  1.36
# ..      ...       ...   ...
# 257 -103.88      50.2  0.70
# 259  -81.55      51.4  0.53
# 389 -100.00      79.7  0.59
# 248   95.12      83.4  0.58
# 247   93.72      83.4  0.58
#
# [690 rows x 8 columns]

# %%
import yfinance as yf

obj = yf.Ticker("")

# %%
#obj.history()
q = obj.get_info()

type(q)
# Out:
# NoneType

# %%
dir(obj)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_analysis',
#  '_base_url',
#  '_data',
#  '_download_options',
#  '_earnings',
#  '_earnings_dates',
#  '_expirations',
#  '_fast_info',
#  '_fetch_ticker_tz',
#  '_financials',
#  '_fix_bad_stock_split',
#  '_fix_missing_div_adjust',
#  '_fix_prices_sudden_change',
#  '_fix_unit_mixups',
#  '_fix_unit_random_mixups',
#  '_fix_unit_switch',
#  '_fix_zeroes',
#  '_fundamentals',
#  '_get_ticker_tz',
#  '_history',
#  '_history_metadata',
#  '_history_metadata_formatted',
#  '_holders',
#  '_isin',
#  '_news',
#  '_options2df',
#  '_quote',
#  '_reconstruct_intervals_batch',
#  '_reconstruct_start_interval',
#  '_shares',
#  '_tz',
#  'actions',
#  'analyst_price_target',
#  'balance_sheet',
#  'balancesheet',
#  'basic_info',
#  'calendar',
#  'capital_gains',
#  'cash_flow',
#  'cashflow',
#  'dividends',
#  'earnings',
#  'earnings_dates',
#  'earnings_forecasts',
#  'earnings_trend',
#  'fast_info',
#  'financials',
#  'get_actions',
#  'get_analyst_price_target',
#  'get_balance_sheet',
#  'get_balancesheet',
#  'get_calendar',
#  'get_capital_gains',
#  'get_cash_flow',
#  'get_cashflow',
#  'get_dividends',
#  'get_earnings',
#  'get_earnings_dates',
#  'get_earnings_forecast',
#  'get_earnings_trend',
#  'get_fast_info',
#  'get_financials',
#  'get_history_metadata',
#  'get_income_stmt',
#  'get_incomestmt',
#  'get_info',
#  'get_institutional_holders',
#  'get_isin',
#  'get_major_holders',
#  'get_mutualfund_holders',
#  'get_news',
#  'get_recommendations',
#  'get_recommendations_summary',
#  'get_rev_forecast',
#  'get_shares',
#  'get_shares_full',
#  'get_splits',
#  'get_sustainability',
#  'get_trend_details',
#  'history',
#  'history_metadata',
#  'income_stmt',
#  'incomestmt',
#  'info',
#  'institutional_holders',
#  'isin',
#  'major_holders',
#  'mutualfund_holders',
#  'news',
#  'option_chain',
#  'options',
#  'quarterly_balance_sheet',
#  'quarterly_balancesheet',
#  'quarterly_cash_flow',
#  'quarterly_cashflow',
#  'quarterly_earnings',
#  'quarterly_financials',
#  'quarterly_income_stmt',
#  'quarterly_incomestmt',
#  'recommendations',
#  'recommendations_summary',
#  'revenue_forecasts',
#  'session',
#  'shares',
#  'splits',
#  'sustainability',
#  'ticker',
#  'trend_details']

# %%
symbol = 'MSFT'
#q = yf.Ticker(symbol).get_info()   
q = yf.Ticker(symbol).info
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[25], line 3
#       1 symbol = 'MSFT'
#       2 #q = yf.Ticker(symbol).get_info()
# ----> 3 q = yf.Ticker(symbol).info
#
# File C:\ProgramData\Anaconda3\envs\option_trader\Lib\site-packages\yfinance\ticker.py:138, in Ticker.info(self)
#     136 @property
#     137 def info(self) -> dict:
# --> 138     return self.get_info()
#
# File C:\ProgramData\Anaconda3\envs\option_trader\Lib\site-packages\yfinance\base.py:1496, in TickerBase.get_info(self, proxy)
#    1494 def get_info(self, proxy=None) -> dict:
#    1495     self._quote.proxy = proxy
# -> 1496     data = self._quote.info
#    1497     return data
#
# File C:\ProgramData\Anaconda3\envs\option_trader\Lib\site-packages\yfinance\scrapers\quote.py:563, in Quote.info(self)
#     560 @property
#     561 def info(self) -> dict:
#     562     if self._info is None:
# --> 563         self._fetch(self.proxy)
#     564         self._fetch_complementary(self.proxy)
#     566     return self._info
#
# File C:\ProgramData\Anaconda3\envs\option_trader\Lib\site-packages\yfinance\scrapers\quote.py:594, in Quote._fetch(self, proxy)
#     592 params_dict["modules"] = modules
#     593 params_dict["ssl"] = "true"
# --> 594 result = self._data.get_raw_json(
#     595     _BASIC_URL_ + f"/{self._data.ticker}", params=params_dict, proxy=proxy
#     596 )
#     597 result["quoteSummary"]["result"][0]["symbol"] = self._data.ticker
#     598 query1_info = next(
#     599     (info for info in result.get("quoteSummary", {}).get("result", []) if info["symbol"] == self._data.ticker),
#     600     None,
#     601 )
#
# File C:\ProgramData\Anaconda3\envs\option_trader\Lib\site-packages\yfinance\data.py:75, in TickerData.get_raw_json(self, url, user_agent_headers, params, proxy, timeout)
#      73 def get_raw_json(self, url, user_agent_headers=None, params=None, proxy=None, timeout=30):
#      74     response = self.get(url, user_agent_headers=user_agent_headers, params=params, proxy=proxy, timeout=timeout)
# ---> 75     response.raise_for_status()
#      76     return response.json()
#
# File C:\ProgramData\Anaconda3\envs\option_trader\Lib\site-packages\requests\models.py:1021, in Response.raise_for_status(self)
#    1016     http_error_msg = (
#    1017         f"{self.status_code} Server Error: {reason} for url: {self.url}"
#    1018     )
#    1020 if http_error_msg:
# -> 1021     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 404 Client Error: Not Found for url: https://query2.finance.yahoo.com/v6/finance/quoteSummary/MSFT?modules=financialData&modules=quoteType&modules=defaultKeyStatistics&modules=assetProfile&modules=summaryDetail&ssl=true

# %%
data = obj.history(period='1y')

# %%
data['Volume'].mean()
# Out:
# 26247631.07569721

# %%
data.groupby('Volume').mean()
# Out:
#                 Open        High         Low       Close  Dividends
# Volume
# 8567800    98.464996   98.940002   97.529999   97.599998        0.0  \
# 13888300  120.320000  121.019997  119.705002  120.559998        0.0
# 14650000  130.770004  132.220001  130.029999  132.169998        0.0
# 14769200  131.589996  131.990005  129.819000  130.270004        0.0
# 15018100  128.369995  129.770004  127.775002  128.770004        0.0
# ...              ...         ...         ...         ...        ...
# 57115100  115.860001  118.440002  114.930000  116.900002        0.0
# 58796100  129.770004  130.100006  126.089996  126.669998        0.0
# 73546000  102.690002  103.580002   98.455002  100.000000        0.0
# 76140300  100.839996  103.489998  100.750000  102.459999        0.0
# 97798600  100.540001  100.610001   93.860001   95.459999        0.0
#
#           Stock Splits
# Volume
# 8567800            0.0
# 13888300           0.0
# 14650000           0.0
# 14769200           0.0
# 15018100           0.0
# ...                ...
# 57115100           0.0
# 58796100           0.0
# 73546000           0.0
# 76140300           0.0
# 97798600           0.0
#
# [251 rows x 6 columns]

# %%
import yahoo_fin.stock_info as si

# %%
si.get_stats('MSFT')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 si.get_stats('MSFT')
#
# File C:\ProgramData\Anaconda3\envs\option_trader\Lib\site-packages\yahoo_fin\stock_info.py:336, in get_stats(ticker, headers)
#     334 table = tables[0]
#     335 for elt in tables[1:]:
# --> 336     table = table.append(elt)
#     338 table.columns = ["Attribute" , "Value"]
#     340 table = table.reset_index(drop = True)
#
# File C:\ProgramData\Anaconda3\envs\option_trader\Lib\site-packages\pandas\core\generic.py:5989, in NDFrame.__getattr__(self, name)
#    5982 if (
#    5983     name not in self._internal_names_set
#    5984     and name not in self._metadata
#    5985     and name not in self._accessors
#    5986     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987 ):
#    5988     return self[name]
# -> 5989 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'append'

# %%
si.get_quote_data('MSFT')
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 si.get_quote_data('MSFT')
#
# File C:\ProgramData\Anaconda3\envs\option_trader\Lib\site-packages\yahoo_fin\stock_info.py:960, in get_quote_data(ticker, headers)
#     956     resp = requests.get(site, headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/39.0.2171.95 Safari/537.36'}
#     957 )
#     959     if not resp.ok:
# --> 960         raise AssertionError("""Invalid response from server.  Check if ticker is
#     961                               valid.""")
#     964     json_result = resp.json()
#     965     info = json_result["quoteResponse"]["result"]
#
# AssertionError: Invalid response from server.  Check if ticker is
#                               valid.
